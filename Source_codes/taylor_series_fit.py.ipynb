# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt

# %%
file_path="./Word_Data/Formant/Formant2/Word2_1_Formant_frq.txt"

# %%
formant=pd.read_csv(file_path,
            delim_whitespace=True,
            header=None,
            names=["time","F1","F2","F3","F4","F5"],
            dtype=np.float64,
            na_values="--undefined--")

# %%
time=formant['time'].values
F1=formant["F1"].values

# %%
plt.plot(time,F1,'b',label='Original')

# %%
plt.plot(time,F1,'b',label='Original')

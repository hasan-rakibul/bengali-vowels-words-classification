# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers as opt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses
import pandas as pd
import seaborn as sns
import shap

# %%
DATA_PATH="./Vowel_Data/Formant/"

# %%
seed=0

# %%
def get_formant(file_path):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    return formant

def get_all_formants(path=DATA_PATH):
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
            
            #for i in range(2,len(individual_formant)):
             #   F_i=individual_formant.loc[i,'F1':'F5'].values
              #  F_i1=individual_formant.loc[i-1,'F1':'F5'].values
              #  F_i2=individual_formant.loc[i-2,'F1':'F5'].values
               # individual_formant.loc[i,['F1_diff2','F2_diff2','F3_diff2','F4_diff2','F5_diff2']]=F_i-2*F_i1+F_i2
            
            length=len(individual_formant)
            F_i=individual_formant.loc[2:,'F1':'F5'].values
            F_i1=individual_formant.loc[1:length-2,'F1':'F5'].values
            F_i2=individual_formant.loc[:length-3,'F1':'F5'].values
            assert len(F_i)==len(F_i1)==len(F_i2)
            individual_formant.loc[2:,['F1_diff2','F2_diff2','F3_diff2','F4_diff2','F5_diff2']]=F_i-2*F_i1+F_i2
            
            individual_formant=individual_formant.dropna()   #drop the first two rows as there are NaN values due to the difference
            
            folder_formant=folder_formant.append(individual_formant,ignore_index=True)
        
        folder_formant['disp(F5-F1)']=folder_formant['F5']-folder_formant['F1']
        folder_formant['disp(F4-F3)']=folder_formant['F4']-folder_formant['F3']
        folder_formant['disp(F5-F3)']=folder_formant['F5']-folder_formant['F3']
        folder_formant['disp(F5-F4)']=folder_formant['F5']-folder_formant['F4']
        
        folder_formant['label']=label_index  #new columns for encoding label
        
        all_formant=all_formant.append(folder_formant,ignore_index=True)
        
        
    return all_formant

def get_train_test(split_ratio=0.8,random_state=42):
    all_formants=get_all_formants()
    
    y=all_formants['label'].values
    
    #all_formants['disp(F5-F1)']=all_formants['F5']-all_formants['F1']
    #all_formants['disp(F4-F3)']=all_formants['F4']-all_formants['F3']
    #all_formants['disp(F5-F3)']=all_formants['F5']-all_formants['F3']
    #all_formants['disp(F5-F4)']=all_formants['F5']-all_formants['F4']
    
    only_formants=all_formants.drop(labels=['label'],axis=1)
    
    normalized_formants=(only_formants-only_formants.mean())/only_formants.std()
    
    X=normalized_formants.values
    

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
def get_formant(file_path):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    return formant

# %%
path=DATA_PATH

# %%
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 276.66it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 452.81it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 450.42it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 454.77it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 440.02it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 449.74it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 470.76it/s]

# %%
individual_formant
# Out:
#      time      F1       F2       F3       F4       F5
# 0   0.025  452.09   948.12  2527.81  4086.58  4740.32
# 1   0.031  444.29   939.36  2557.82  4073.15  4700.37
# 2   0.038  426.03   929.72  2580.59  4060.06  4590.44
# 3   0.044  417.61   938.16  2584.27  4010.16  4569.61
# 4   0.050  414.34   953.77  2583.57  4015.34  4585.22
# 5   0.056  411.11   965.89  2593.48  4058.24  4652.08
# 6   0.062  410.56   972.72  2640.72  4045.01  4592.00
# 7   0.069  415.33   984.43  2678.19  4048.64  4485.93
# 8   0.075  420.64   985.92  2637.95  4054.00  4509.31
# 9   0.081  427.85   975.94  2632.97  4055.06  4516.11
# 10  0.088  434.55   992.99  2677.83  4073.53  4459.50
# 11  0.094  437.59  1016.11  2607.29  4059.27  4356.35
# 12  0.100  438.75  1011.89  2584.35  4030.15  4356.70
# 13  0.106  433.14   994.73  2598.70  3975.70  4391.69
# 14  0.113  427.74   980.19  2611.96  3965.82  4427.38
# 15  0.119  419.44   980.40  2618.60  3974.84  4454.15
# 16  0.125  413.65   982.59  2631.47  4002.56  4448.58
# 17  0.131  406.04   979.33  2628.63  3984.54  4430.34
# 18  0.138  401.04   972.53  2625.51  3963.62  4430.13
# 19  0.144  412.56   955.04  2647.29  4010.02  4484.68
# 20  0.150  417.50   941.66  2662.24  4044.07  4497.17
# 21  0.156  420.04   928.12  2672.68  4041.29  4492.86
# 22  0.163  436.54   879.28  2679.17  4066.78  4541.83
# 23  0.169  493.13   781.98  2777.38  4080.27  4549.05
# 24  0.175  450.02   950.18  3113.42  4074.09  4414.41
# 25  0.181  450.56   959.89  3188.13  4029.91  4456.71
# 26  0.188  447.85  1009.41  3301.00  4005.14  4492.79
# 27  0.194  444.47  1026.16  3218.98  3971.43  4533.06
# 28  0.200  442.42  1013.39  2954.39  3979.99  4550.18
# 29  0.206  459.18  1005.80  3045.15  3990.13  4491.49
#
#        disp(F5-F4)  label
# 0           945.22      0
# 1           887.63      0
# 2           997.06      0
# 3          1037.92      0
# 4           999.30      0
# ...            ...    ...
# 13596       489.11      6
# 13597       471.41      6
# 13598       440.09      6
# 13599       473.07      6
# 13600       486.90      6
#
# [13601 rows x 16 columns]

# %%
normalized_formants=(all_formants-all_formants.mean())/all_formants.std()

# %%
normalized_formants
# Out:
#            time        F1        F2        F3        F4        F5  F1_diff2  \
# 0     -1.407946  1.180004  0.015120 -0.429702  0.367335  0.144299 -0.158763
# 1     -1.357599  1.162203  0.028224 -0.404425  0.342279  0.020442  0.182885
# 2     -1.307253  1.165996  0.028783 -0.468727  0.188529  0.102298  0.040004
# 3     -1.256906  1.180838 -0.048808 -0.463377  0.016022  0.045126  0.020229
# 4     -1.206559  1.187174 -0.072371 -0.347561  0.112023  0.048055 -0.016429
# ...         ...       ...       ...       ...       ...       ...       ...
# 13596  1.050653 -0.305083  1.559195  1.393918  0.872136 -0.300579 -0.101861
# 13597  1.109391 -0.362613  1.485068  1.302570  0.951529 -0.272257 -0.000875
# 13598  1.159738 -0.400967  1.390949  1.437930  0.856434 -0.401717  0.035471
# 13599  1.210084 -0.392504  1.296190  1.057084  0.720200 -0.445574  0.087292
# 13600  1.260431 -0.427356  1.348908  0.923515  0.761387 -0.389020 -0.081695
#
#        F2_diff2  F3_diff2  F4_diff2  F5_diff2  disp(F5-F1)  disp(F4-F3)  \
# 0     -0.051153  0.264113 -0.007932 -0.161293    -0.391253     0.826672
# 1     -0.018269 -0.137359 -0.218520 -0.004876    -0.513821     0.774683
# 2     -0.020010 -0.116120 -0.184666  0.283076    -0.429145     0.695026
# 3     -0.139681  0.089685 -0.026166 -0.191840    -0.496344     0.521111
# 4      0.101426  0.142437  0.387991  0.082480    -0.496171     0.488305
# ...         ...       ...       ...       ...          ...          ...
# 13596 -0.056924 -0.635989  0.239984  0.024117    -0.176807    -0.670881
# 13597 -0.140974  0.563826 -0.074504 -0.106916    -0.120401    -0.493873
# 13598 -0.033592  0.292680 -0.250687 -0.217676    -0.239416    -0.734192
# 13599  0.001705 -0.667531 -0.058437  0.117612    -0.289618    -0.451464
# 13600  0.271889  0.319263  0.256670  0.138010    -0.213854    -0.265622
#
#        disp(F5-F3)  disp(F5-F4)     label
# 0         0.493100    -0.151850 -1.632485
# 1         0.352774    -0.269066 -1.632485
# 2         0.484710    -0.046337 -1.632485
# 3         0.425140     0.036827 -1.632485
# 4         0.332590    -0.041778 -1.632485
# ...            ...          ...       ...
# 13596    -1.437940    -1.080197  1.447261
# 13597    -1.335385    -1.116222  1.447261
# 13598    -1.571771    -1.179970  1.447261
# 13599    -1.300457    -1.112844  1.447261
# 13600    -1.135892    -1.084695  1.447261
#
# [13601 rows x 16 columns]

# %%
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 119.39it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 128.76it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 105.22it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 113.02it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 104.13it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 119.15it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 121.39it/s]

# %%
np.random.seed(seed)

# %%
model_v=Sequential()
#model_v.add(Dense(128, activation='relu', input_shape=(6,)))
#model_v.add(Dense(64, activation='relu'))
model_v.add(Dense(32, activation='tanh',input_shape=(X_train.shape[1],)))
model_v.add(Dense(16, activation='tanh'))
model_v.add(Dense(7, activation='softmax'))

# %%
model_v.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    #metrics=['AUC'],
    #metrics=['accuracy']#,
    metrics=[['accuracy','AUC']]
)

# %%
history_v=model_v.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 340ms/step - loss: 2.0839 - accuracy: 0.1241 - auc: 0.4858 - val_loss: 2.0168 - val_accuracy: 0.1661 - val_auc: 0.5203
# Epoch 2/50
# 1/1 [==============================] - 0s 98ms/step - loss: 2.0167 - accuracy: 0.1635 - auc: 0.5200 - val_loss: 1.9597 - val_accuracy: 0.2172 - val_auc: 0.5535
# Epoch 3/50
# 1/1 [==============================] - 0s 94ms/step - loss: 1.9563 - accuracy: 0.2075 - auc: 0.5560 - val_loss: 1.9087 - val_accuracy: 0.2547 - val_auc: 0.5882
# Epoch 4/50
# 1/1 [==============================] - 0s 88ms/step - loss: 1.9024 - accuracy: 0.2432 - auc: 0.5927 - val_loss: 1.8633 - val_accuracy: 0.2731 - val_auc: 0.6226
# Epoch 5/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.8543 - accuracy: 0.2753 - auc: 0.6299 - val_loss: 1.8227 - val_accuracy: 0.3021 - val_auc: 0.6548
# Epoch 6/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.8112 - accuracy: 0.3071 - auc: 0.6644 - val_loss: 1.7859 - val_accuracy: 0.3179 - val_auc: 0.6835
# Epoch 7/50
# 1/1 [==============================] - 0s 126ms/step - loss: 1.7723 - accuracy: 0.3244 - auc: 0.6948 - val_loss: 1.7521 - val_accuracy: 0.3289 - val_auc: 0.7080
# Epoch 8/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1.7369 - accuracy: 0.3386 - auc: 0.7205 - val_loss: 1.7207 - val_accuracy: 0.3414 - val_auc: 0.7284
# Epoch 9/50
# 1/1 [==============================] - 0s 83ms/step - loss: 1.7041 - accuracy: 0.3549 - auc: 0.7412 - val_loss: 1.6909 - val_accuracy: 0.3572 - val_auc: 0.7457
# 1/1 [==============================] - 0s 79ms/step - loss: 1.1664 - accuracy: 0.6007 - auc: 0.8950 - val_loss: 1.1703 - val_accuracy: 0.5957 - val_auc: 0.8934
# Epoch 41/50
# 1/1 [==============================] - 0s 84ms/step - loss: 1.1569 - accuracy: 0.6025 - auc: 0.8968 - val_loss: 1.1612 - val_accuracy: 0.6020 - val_auc: 0.8951
# Epoch 42/50
# 1/1 [==============================] - 0s 77ms/step - loss: 1.1477 - accuracy: 0.6051 - auc: 0.8985 - val_loss: 1.1523 - val_accuracy: 0.6005 - val_auc: 0.8968
# Epoch 43/50
# 1/1 [==============================] - 0s 80ms/step - loss: 1.1387 - accuracy: 0.6061 - auc: 0.9002 - val_loss: 1.1437 - val_accuracy: 0.6001 - val_auc: 0.8983
# Epoch 44/50
# 1/1 [==============================] - 0s 102ms/step - loss: 1.1299 - accuracy: 0.6085 - auc: 0.9018 - val_loss: 1.1352 - val_accuracy: 0.6075 - val_auc: 0.8997
# Epoch 45/50
# 1/1 [==============================] - 0s 82ms/step - loss: 1.1212 - accuracy: 0.6108 - auc: 0.9034 - val_loss: 1.1270 - val_accuracy: 0.6101 - val_auc: 0.9013
# Epoch 46/50
# 1/1 [==============================] - 0s 77ms/step - loss: 1.1127 - accuracy: 0.6128 - auc: 0.9049 - val_loss: 1.1189 - val_accuracy: 0.6134 - val_auc: 0.9027
# Epoch 47/50
# 1/1 [==============================] - 0s 115ms/step - loss: 1.1043 - accuracy: 0.6148 - auc: 0.9065 - val_loss: 1.1110 - val_accuracy: 0.6141 - val_auc: 0.9042
# Epoch 48/50
# 1/1 [==============================] - 0s 79ms/step - loss: 1.0960 - accuracy: 0.6175 - auc: 0.9079 - val_loss: 1.1031 - val_accuracy: 0.6156 - val_auc: 0.9056
# Epoch 49/50
# 1/1 [==============================] - 0s 78ms/step - loss: 1.0879 - accuracy: 0.6193 - auc: 0.9094 - val_loss: 1.0954 - val_accuracy: 0.6174 - val_auc: 0.9069
# Epoch 50/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.0798 - accuracy: 0.6215 - auc: 0.9108 - val_loss: 1.0877 - val_accuracy: 0.6196 - val_auc: 0.9082

# %%
e=shap.DeepExplainer(model_v,X_test)
shape_values=e.shap_values(X_test)
shap.summary_plot(shape_values,X_test)

# %%
model_v.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 32)                352
# _________________________________________________________________
# dense_43 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_44 (Dense)             (None, 7)                 119
# =================================================================
# Total params: 999
# Trainable params: 999
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_dict=history_v.history

loss_v=history_dict['loss']
val_loss_v=history_dict['val_loss']

epochs=range(1,len(loss_v)+1)

acc_v=history_dict['accuracy']
val_acc_v=history_dict['val_accuracy']

auc_v=history_dict['auc']
val_auc_v=history_dict['val_auc']

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'bo',label='Training loss')
plt.plot(epochs,val_loss_v,'b',label='Validation loss')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_vowel_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'bo',label='Training acc')
plt.plot(epochs,val_acc_v,'b',label='Validation acc')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_vowel_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_v,'bo',label='Training AUC')
plt.plot(epochs,val_auc_v,'b',label='Validation AUC')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/AUC_vowel_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
DATA_PATH="./Word_Data/Formant/"

# %%
def get_formant(file_path):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    return formant

def get_all_formants(path=DATA_PATH):
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
            
            #for i in range(2,len(individual_formant)):
             #   F_i=individual_formant.loc[i,'F1':'F5'].values
              #  F_i1=individual_formant.loc[i-1,'F1':'F5'].values
              #  F_i2=individual_formant.loc[i-2,'F1':'F5'].values
               # individual_formant.loc[i,['F1_diff2','F2_diff2','F3_diff2','F4_diff2','F5_diff2']]=F_i-2*F_i1+F_i2
            
            length=len(individual_formant)
            F_i=individual_formant.loc[2:,'F1':'F5'].values
            F_i1=individual_formant.loc[1:length-2,'F1':'F5'].values
            F_i2=individual_formant.loc[:length-3,'F1':'F5'].values
            assert len(F_i)==len(F_i1)==len(F_i2)
            individual_formant.loc[2:,['F1_diff2','F2_diff2','F3_diff2','F4_diff2','F5_diff2']]=F_i-2*F_i1+F_i2
            
            individual_formant=individual_formant.dropna()   #drop the first two rows as there are NaN values due to the difference
            
            folder_formant=folder_formant.append(individual_formant,ignore_index=True)
        
        folder_formant['disp(F5-F1)']=folder_formant['F5']-folder_formant['F1']
        folder_formant['disp(F4-F3)']=folder_formant['F4']-folder_formant['F3']
        folder_formant['disp(F5-F3)']=folder_formant['F5']-folder_formant['F3']
        folder_formant['disp(F5-F4)']=folder_formant['F5']-folder_formant['F4']
        
        folder_formant['label']=label_index  #new columns for encoding label
        
        all_formant=all_formant.append(folder_formant,ignore_index=True)
        
        
    return all_formant

def get_train_test(split_ratio=0.8,random_state=42):
    all_formants=get_all_formants()
    
    y=all_formants['label'].values
    
    #all_formants['disp(F5-F1)']=all_formants['F5']-all_formants['F1']
    #all_formants['disp(F4-F3)']=all_formants['F4']-all_formants['F3']
    #all_formants['disp(F5-F3)']=all_formants['F5']-all_formants['F3']
    #all_formants['disp(F5-F4)']=all_formants['F5']-all_formants['F4']
    
    only_formants=all_formants.drop(labels=['label'],axis=1)
    
    normalized_formants=(only_formants-only_formants.mean())/only_formants.std()
    
    X=normalized_formants.values
    

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
np.random.seed(seed)
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 73.34it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 78.35it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 74.96it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 118.02it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 102.75it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 115.16it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 103.61it/s]

# %%
model_w=Sequential()
#model_w.add(Dense(128, activation='tanh', input_shape=(6,)))
#model_w.add(Dense(64, activation='tanh'))
model_w.add(Dense(32, activation='tanh',input_shape=(X_train.shape[1],)))
model_w.add(Dense(16, activation='tanh'))
model_w.add(Dense(7, activation='softmax'))

# %%
model_w.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    #metrics=['AUC'],
    #metrics=['accuracy']#,
    metrics=[['accuracy','AUC']]
)

# %%
history_w=model_w.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 382ms/step - loss: 2.0808 - accuracy: 0.1357 - auc: 0.4989 - val_loss: 2.0295 - val_accuracy: 0.1519 - val_auc: 0.5135
# Epoch 2/50
# 1/1 [==============================] - 0s 104ms/step - loss: 2.0221 - accuracy: 0.1514 - auc: 0.5215 - val_loss: 1.9772 - val_accuracy: 0.1814 - val_auc: 0.5420
# Epoch 3/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.9714 - accuracy: 0.1833 - auc: 0.5488 - val_loss: 1.9332 - val_accuracy: 0.2216 - val_auc: 0.5719
# Epoch 4/50
# 1/1 [==============================] - 0s 126ms/step - loss: 1.9292 - accuracy: 0.2190 - auc: 0.5774 - val_loss: 1.8974 - val_accuracy: 0.2533 - val_auc: 0.5983
# Epoch 5/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.8951 - accuracy: 0.2446 - auc: 0.6026 - val_loss: 1.8687 - val_accuracy: 0.2710 - val_auc: 0.6198
# Epoch 6/50
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8682 - accuracy: 0.2582 - auc: 0.6230 - val_loss: 1.8458 - val_accuracy: 0.2726 - val_auc: 0.6366
# Epoch 7/50
# Epoch 38/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.5883 - accuracy: 0.3695 - auc: 0.7707 - val_loss: 1.5827 - val_accuracy: 0.3623 - val_auc: 0.7704
# Epoch 39/50
# 1/1 [==============================] - 0s 133ms/step - loss: 1.5849 - accuracy: 0.3689 - auc: 0.7715 - val_loss: 1.5794 - val_accuracy: 0.3610 - val_auc: 0.7712
# Epoch 40/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.5819 - accuracy: 0.3692 - auc: 0.7723 - val_loss: 1.5762 - val_accuracy: 0.3594 - val_auc: 0.7720
# Epoch 41/50
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5790 - accuracy: 0.3687 - auc: 0.7730 - val_loss: 1.5733 - val_accuracy: 0.3602 - val_auc: 0.7726
# Epoch 42/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.5764 - accuracy: 0.3700 - auc: 0.7736 - val_loss: 1.5705 - val_accuracy: 0.3591 - val_auc: 0.7734
# Epoch 43/50
# 1/1 [==============================] - 0s 92ms/step - loss: 1.5739 - accuracy: 0.3697 - auc: 0.7742 - val_loss: 1.5678 - val_accuracy: 0.3610 - val_auc: 0.7742
# Epoch 44/50
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5715 - accuracy: 0.3687 - auc: 0.7749 - val_loss: 1.5653 - val_accuracy: 0.3623 - val_auc: 0.7748
# Epoch 45/50
# 1/1 [==============================] - 0s 93ms/step - loss: 1.5692 - accuracy: 0.3703 - auc: 0.7756 - val_loss: 1.5629 - val_accuracy: 0.3636 - val_auc: 0.7755
# Epoch 46/50
# 1/1 [==============================] - 0s 99ms/step - loss: 1.5669 - accuracy: 0.3719 - auc: 0.7762 - val_loss: 1.5606 - val_accuracy: 0.3654 - val_auc: 0.7761
# Epoch 47/50
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5646 - accuracy: 0.3716 - auc: 0.7769 - val_loss: 1.5583 - val_accuracy: 0.3672 - val_auc: 0.7769
# Epoch 48/50
# 1/1 [==============================] - 0s 104ms/step - loss: 1.5623 - accuracy: 0.3730 - auc: 0.7776 - val_loss: 1.5560 - val_accuracy: 0.3680 - val_auc: 0.7775
# Epoch 49/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.5601 - accuracy: 0.3740 - auc: 0.7783 - val_loss: 1.5537 - val_accuracy: 0.3709 - val_auc: 0.7782
# Epoch 50/50
# 1/1 [==============================] - 0s 95ms/step - loss: 1.5578 - accuracy: 0.3753 - auc: 0.7790 - val_loss: 1.5514 - val_accuracy: 0.3717 - val_auc: 0.7787

# %%
e=shap.DeepExplainer(model_w,X_test)
shape_values=e.shap_values(X_test)
shap.summary_plot(shape_values,X_test)

# %%
history_dict=history_w.history
loss_w=history_dict['loss']
val_loss_w=history_dict['val_loss']

epochs=range(1,len(loss_v)+1)

acc_w=history_dict['accuracy']
val_acc_w=history_dict['val_accuracy']

auc_w=history_dict['auc']
val_auc_w=history_dict['val_auc']

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_w,'bo',label='Training loss')
plt.plot(epochs,val_loss_w,'b',label='Validation loss')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_word_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_w,'bo',label='Training acc')
plt.plot(epochs,val_acc_w,'b',label='Validation acc')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_word_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_w,'bo',label='Training AUC')
plt.plot(epochs,val_auc_w,'b',label='Validation AUC')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/AUC_word_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
#COMPARE

# %%
epochs=range(1,len(loss_v)+1)

# %%
save_specifier='fromant_diff_disp_32_16_tanh_softmax_adam_0.005_batchfull_scaled'

# %%
#sns.reset()
#sns.reset_orig()
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'r',label='Vowel')
plt.plot(epochs,loss_w,'b',label='Word')
plt.title('Loss comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('./Result/New_without_CNN/loss_compare_'+save_specifier+'.pdf',format='pdf',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'r',label='Vowel')
plt.plot(epochs,acc_w,'b',label='Word')
plt.title('Accuracy comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig('./Result/New_without_CNN/accuracy_compare_'+save_specifier+'.pdf',format='pdf',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_v,'r',label='Vowel')
plt.plot(epochs,auc_w,'b',label='Word')
plt.title('AUC comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
plt.savefig('./Result/New_without_CNN/AUC_compare_'+save_specifier+'.pdf',format='pdf',dpi=600)

# %%
all_compare_df=pd.DataFrame({'loss_v':loss_v,
                      'val_loss_v':val_loss_v,
                      'acc_v':acc_v,
                      'val_acc_v':val_acc_v,
                      'auc_v':auc_v,
                      'val_auc_v':val_auc_v,
                      'loss_w':loss_w,
                      'val_loss_w':val_loss_w,
                      'acc_w':acc_w,
                      'val_acc_w':val_acc_w,
                      'auc_w':auc_w,
                      'val_auc_w':val_auc_w
                     })

all_compare_df.to_csv('./Result/New_without_CNN/all_compare_data_'+save_specifier+'.csv')

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  1.510234    1.498732  0.366437   0.370279  0.796772   0.800146  1.708708
# 46  1.504479    1.498546  0.365201   0.367102  0.797813   0.798793  1.707437
# 47  1.500465    1.493217  0.364848   0.376633  0.798146   0.801928  1.706840
# 48  1.497878    1.487364  0.368114   0.381221  0.799064   0.803229  1.704514

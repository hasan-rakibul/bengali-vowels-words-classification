# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import librosa

# %%
# VOWEL
# signal, fs= librosa.load('/home/rakibul/WORK/RESEARCH/Speech_Recognition/MAIN STUDY/GitHub Repo/Vowel_Data/Vowel/vowel4/vowel4_21.wav', mono=True, sr=None)

# WORD
signal, fs= librosa.load('/home/rakibul/WORK/RESEARCH/Speech_Recognition/MAIN STUDY/GitHub Repo/Word_Data/Word/Word4/Word4_1.wav', mono=True, sr=None)

# %%
time=np.linspace(0,len(signal)/fs, num=len(signal))

# %%
plt.figure()
plt.plot(time,signal,'k')
plt.xlabel('Time (second)')
plt.ylabel('Intensity')
plt.tight_layout()

# VOWEL
# plt.savefig('/home/rakibul/WORK/RESEARCH/Speech_Recognition/MAIN STUDY/GitHub Repo/Result/New_without_CNN/vowel4_wave_vs_time.pdf',format='pdf',dpi=600)

# WORD
plt.savefig('/home/rakibul/WORK/RESEARCH/Speech_Recognition/MAIN STUDY/GitHub Repo/Result/New_without_CNN/word4_wave_vs_time.pdf',format='pdf',dpi=600)

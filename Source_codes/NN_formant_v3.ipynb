# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers as opt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses
import pandas as pd

# %%
DATA_PATH="./Vowel_Data/Formant/"
n_time_sample=50

# %%
seed=0

# %%
def get_formant(file_path,max_len=n_time_sample):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    if (max_len > formant.shape[0]):
        required_rows=max_len-formant.shape[0]
        new_data=pd.DataFrame(np.zeros((required_rows,6)),columns=["time","F1","F2","F3","F4","F5"])  #empty structure to configure
        time_step=formant.iloc[1]['time']-formant.iloc[0]['time']
        new_data['time']=[formant.iloc[-1]['time']+i*time_step for i in range(1,required_rows+1)]   #new time will incremented as previous time data
        new_data.iloc[:,1:]=formant.iloc[-1,1:].values  #formant values of last existing sample is taken as new formant values
        formant=formant.append(new_data,ignore_index=True)  #new data is appended to the existing
    else:
        formant=formant.iloc[:max_len]  #truncate up to fixed length
    return formant

def get_all_formants(path=DATA_PATH):
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
            folder_formant=folder_formant.append(individual_formant,ignore_index=True)
        
        folder_formant['label']=label_index  #new columns for encoding label
        
        all_formant=all_formant.append(folder_formant,ignore_index=True)
        
    return all_formant

def get_train_test(split_ratio=0.8,random_state=42):
    all_formants=get_all_formants()
    
    X=all_formants.drop(labels=['label'],axis=1).values
    y=all_formants['label'].values

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
np.random.seed(seed)
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 88.15it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 230.90it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 228.35it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 229.47it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 329.23it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 228.37it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 252.75it/s]

# %%
model_v=Sequential()
model_v.add(Dense(128, activation='tanh', input_shape=(6,)))
model_v.add(Dense(64, activation='tanh'))
model_v.add(Dense(32, activation='tanh'))
model_v.add(Dense(16, activation='tanh'))
model_v.add(Dense(7, activation='softmax'))

# %%
model_v.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_v=model_v.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 177ms/step - loss: 2.0794 - accuracy: 0.1073 - val_loss: 1.9802 - val_accuracy: 0.2729
# Epoch 2/50
# 1/1 [==============================] - 0s 66ms/step - loss: 1.9793 - accuracy: 0.2788 - val_loss: 1.9387 - val_accuracy: 0.1432
# Epoch 3/50
# 1/1 [==============================] - 0s 60ms/step - loss: 1.9387 - accuracy: 0.1429 - val_loss: 1.9156 - val_accuracy: 0.1657
# Epoch 4/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.9155 - accuracy: 0.1661 - val_loss: 1.8701 - val_accuracy: 0.1993
# Epoch 5/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8701 - accuracy: 0.2024 - val_loss: 1.8257 - val_accuracy: 0.2796
# Epoch 6/50
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8264 - accuracy: 0.2778 - val_loss: 1.7755 - val_accuracy: 0.2686
# Epoch 7/50
# 1/1 [==============================] - 0s 58ms/step - loss: 1
50
# 1/1 [==============================] - 0s 51ms/step - loss: 1.2790 - accuracy: 0.4843 - val_loss: 1.2839 - val_accuracy: 0.4871
# Epoch 34/50
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2724 - accuracy: 0.4925 - val_loss: 1.2876 - val_accuracy: 0.4864
# Epoch 35/50
# 1/1 [==============================] - 0s 53ms/step - loss: 1.2729 - accuracy: 0.4897 - val_loss: 1.2897 - val_accuracy: 0.5168
# Epoch 36/50
# 1/1 [==============================] - 0s 64ms/step - loss: 1.2706 - accuracy: 0.5162 - val_loss: 1.2676 - val_accuracy: 0.4886
# Epoch 37/50
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2617 - accuracy: 0.4869 - val_loss: 1.2719 - val_accuracy: 0.4661
# Epoch 38/50
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2627 - accuracy: 0.4700 - val_loss: 1.2722 - val_accuracy: 0.4621
# Epoch 39/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.2700 - accuracy: 0.4555 - val_loss: 1.2442 - val_accuracy: 0.4950
# Epoch 40/50
# 1/1 [==============================] - 0s 43ms/step - loss: 1.2459 - accuracy: 0.4922 - val_loss: 1.2551 - val_accuracy: 0.4696
# Epoch 41/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.2568 - accuracy: 0.4713 - val_loss: 1.2176 - val_accuracy: 0.5211
# Epoch 42/50
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2129 - accuracy: 0.5194 - val_loss: 1.2461 - val_accuracy: 0.5082
# Epoch 43/50
# 1/1 [==============================] - 0s 49ms/step - loss: 1.2430 - accuracy: 0.5058 - val_loss: 1.2290 - val_accuracy: 0.5071
# Epoch 44/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.2226 - accuracy: 0.5109 - val_loss: 1.2433 - val_accuracy: 0.5046
# Epoch 45/50
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2359 - accuracy: 0.4975 - val_loss: 1.2564 - val_accuracy: 0.5050
# Epoch 46/50
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2570 - accuracy: 0.4939 - val_loss: 1.2262 - val_accuracy: 0.5243
# Epoch 47/50
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2281 - accuracy: 0.5013 - val_loss: 1.2230 - val_accuracy: 0.5082
# Epoch 48/50
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2336 - accuracy: 0.4972 - val_loss: 1.2269 - val_accuracy: 0.5014
# Epoch 49/50
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2344 - accuracy: 0.4980 - val_loss: 1.2171 - val_accuracy: 0.5075
# Epoch 50/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2144 - accuracy: 0.5054 - val_loss: 1.1975 - val_accuracy: 0.5107

# %%
history_dict=history_v.history

# %%
loss_v=history_dict['loss']
val_loss_v=history_dict['val_loss']
epochs=range(1,len(loss_v)+1)

plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'bo',label='Training loss')
plt.plot(epochs,val_loss_v,'b',label='Validation loss')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_vowel_128_64_32_16_tanh_softmax_adam_batch200.svg',format='svg', dpi=600)

# %%
plt.clf()
acc_v=history_dict['accuracy']
val_acc_v=history_dict['val_accuracy']

plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'bo',label='Training acc')
plt.plot(epochs,val_acc_v,'b',label='Validation acc')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_vowel_128_64_32_16_tanh_softmax_adam_batch200.svg',format='svg', dpi=600)

# %%
DATA_PATH="./Word_Data/Formant/"
n_time_sample=70

# %%
def get_formant(file_path,max_len=n_time_sample):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    if (max_len > formant.shape[0]):
        required_rows=max_len-formant.shape[0]
        new_data=pd.DataFrame(np.zeros((required_rows,6)),columns=["time","F1","F2","F3","F4","F5"])  #empty structure to configure
        time_step=formant.iloc[1]['time']-formant.iloc[0]['time']
        new_data['time']=[formant.iloc[-1]['time']+i*time_step for i in range(1,required_rows+1)]   #new time will incremented as previous time data
        new_data.iloc[:,1:]=formant.iloc[-1,1:].values  #formant values of last existing sample is taken as new formant values
        formant=formant.append(new_data,ignore_index=True)  #new data is appended to the existing
    else:
        formant=formant.iloc[:max_len]  #truncate up to fixed length
    return formant

def get_all_formants(path=DATA_PATH):
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
            folder_formant=folder_formant.append(individual_formant,ignore_index=True)
        
        folder_formant['label']=label_index  #new columns for encoding label
        
        all_formant=all_formant.append(folder_formant,ignore_index=True)
        
    return all_formant

def get_train_test(split_ratio=0.8,random_state=42):
    all_formants=get_all_formants()
    
    X=all_formants.drop(labels=['label'],axis=1).values
    y=all_formants['label'].values

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
np.random.seed(seed)
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 222.89it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 207.54it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 199.89it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 302.09it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 312.08it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 233.84it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 152.31it/s]

# %%
model_w=Sequential()
model_w.add(Dense(128, activation='tanh', input_shape=(6,)))
model_w.add(Dense(64, activation='tanh'))
model_w.add(Dense(32, activation='tanh'))
model_w.add(Dense(16, activation='tanh'))
model_w.add(Dense(7, activation='softmax'))

# %%
model_w.compile(
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_w=model_w.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 160ms/step - loss: 2.1772 - accuracy: 0.1521 - val_loss: 2.1233 - val_accuracy: 0.1819
# Epoch 2/50
# 1/1 [==============================] - 0s 71ms/step - loss: 2.1290 - accuracy: 0.1661 - val_loss: 2.0969 - val_accuracy: 0.1426
# Epoch 3/50
# 1/1 [==============================] - 0s 80ms/step - loss: 2.0971 - accuracy: 0.1409 - val_loss: 1.9558 - val_accuracy: 0.1684
# Epoch 4/50
# 1/1 [==============================] - 0s 60ms/step - loss: 1.9586 - accuracy: 0.1630 - val_loss: 1.9053 - val_accuracy: 0.1923
# Epoch 5/50
# 1/1 [==============================] - 0s 49ms/step - loss: 1.9054 - accuracy: 0.1957 - val_loss: 1.9047 - val_accuracy: 0.1441
# Epoch 6/50
# 1/1 [==============================] - 0s 74ms/step - loss: 1.9057 - accuracy: 0.1426 - val_loss: 1.8852 - val_accuracy: 0.1898
# Epoch 7/50
# 1/1 [==============================] - 0s 50ms/step - loss: 1.8854 - accuracy: 0.1885 - val_loss: 1.8650 - val_accuracy: 0.1849
# Epoch 8/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1.8657 - accuracy: 0.1873 - val_loss: 1.8477 - val_accuracy: 0.2176
# Epoch 9/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1
50
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6646 - accuracy: 0.3165 - val_loss: 1.6570 - val_accuracy: 0.3265
# Epoch 36/50
# 1/1 [==============================] - 0s 64ms/step - loss: 1.6654 - accuracy: 0.3175 - val_loss: 1.6549 - val_accuracy: 0.3191
# Epoch 37/50
# 1/1 [==============================] - 0s 48ms/step - loss: 1.6649 - accuracy: 0.3116 - val_loss: 1.6511 - val_accuracy: 0.3260
# Epoch 38/50
# 1/1 [==============================] - 0s 71ms/step - loss: 1.6608 - accuracy: 0.3135 - val_loss: 1.6568 - val_accuracy: 0.3245
# Epoch 39/50
# 1/1 [==============================] - 0s 55ms/step - loss: 1.6651 - accuracy: 0.3193 - val_loss: 1.6523 - val_accuracy: 0.3293
# Epoch 40/50
# 1/1 [==============================] - 0s 49ms/step - loss: 1.6598 - accuracy: 0.3230 - val_loss: 1.6518 - val_accuracy: 0.3237
# Epoch 41/50
# 1/1 [==============================] - 0s 53ms/step - loss: 1.6593 - accuracy: 0.3185 - val_loss: 1.6491 - val_accuracy: 0.3337
# Epoch 42/50
# 1/1 [==============================] - 0s 49ms/step - loss: 1.6556 - accuracy: 0.3244 - val_loss: 1.6492 - val_accuracy: 0.3293
# Epoch 43/50
# 1/1 [==============================] - 0s 54ms/step - loss: 1.6581 - accuracy: 0.3171 - val_loss: 1.6429 - val_accuracy: 0.3281
# Epoch 44/50
# 1/1 [==============================] - 0s 50ms/step - loss: 1.6510 - accuracy: 0.3171 - val_loss: 1.6488 - val_accuracy: 0.3189
# Epoch 45/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1.6563 - accuracy: 0.3114 - val_loss: 1.6383 - val_accuracy: 0.3255
# Epoch 46/50
# 1/1 [==============================] - 0s 56ms/step - loss: 1.6458 - accuracy: 0.3175 - val_loss: 1.6408 - val_accuracy: 0.3204
# Epoch 47/50
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6466 - accuracy: 0.3154 - val_loss: 1.6438 - val_accuracy: 0.3196
# Epoch 48/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1.6492 - accuracy: 0.3122 - val_loss: 1.6347 - val_accuracy: 0.3247
# Epoch 49/50
# 1/1 [==============================] - 0s 51ms/step - loss: 1.6399 - accuracy: 0.3165 - val_loss: 1.6317 - val_accuracy: 0.3186
# Epoch 50/50
# 1/1 [==============================] - 0s 47ms/step - loss: 1.6383 - accuracy: 0.3155 - val_loss: 1.6326 - val_accuracy: 0.3286

# %%
history_dict=history_w.history

# %%
loss_w=history_dict['loss']
val_loss_w=history_dict['val_loss']
epochs=range(1,len(loss_v)+1)

plt.figure(figsize=(10,4))
plt.plot(epochs,loss_w,'bo',label='Training loss')
plt.plot(epochs,val_loss_w,'b',label='Validation loss')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_vowel_128_64_32_16_tanh_softmax_adam_batch200.svg',format='svg', dpi=600)

# %%
plt.clf()
acc_w=history_dict['accuracy']
val_acc_w=history_dict['val_accuracy']

plt.figure(figsize=(10,4))
plt.plot(epochs,acc_w,'bo',label='Training acc')
plt.plot(epochs,val_acc_w,'b',label='Validation acc')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_vowel_128_64_32_16_tanh_softmax_adam_batch200.svg',format='svg', dpi=600)

# %%
#COMPARE

# %%
epochs=range(1,len(loss_v)+1)

# %%
save_specifier='fromant_128_64_32_16_tanh_softmax_adam_0.005_batchfull'

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'r',label='Vowel')
plt.plot(epochs,loss_w,'b',label='Word')
plt.title('Loss comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('./Result/New_without_CNN/loss_compare_'+save_specifier+'.svg',format='svg',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'r',label='Vowel')
plt.plot(epochs,acc_w,'b',label='Word')
plt.title('Accuracy comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig('./Result/New_without_CNN/accuracy_compate_'+save_specifier+'.svg',format='svg',dpi=600)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers as opt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses
import pandas as pd
import seaborn as sns
import shap

# %%
DATA_PATH="./Vowel_Data/Formant/"

# %%
seed=0

# %%
def get_formant(file_path):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    return formant

def get_all_formants(path=DATA_PATH):
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
            folder_formant=folder_formant.append(individual_formant,ignore_index=True)
        
        folder_formant['label']=label_index  #new columns for encoding label
        
        all_formant=all_formant.append(folder_formant,ignore_index=True)
        
    return all_formant

def get_train_test(split_ratio=0.8,random_state=42):
    all_formants=get_all_formants()
    
    all_formants['disp(F5-F1)']=all_formants['F5']-all_formants['F1']
    all_formants['disp(F4-F3)']=all_formants['F4']-all_formants['F3']
    all_formants['disp(F5-F3)']=all_formants['F5']-all_formants['F3']
    all_formants['disp(F5-F4)']=all_formants['F5']-all_formants['F4']
    
    X=all_formants.drop(labels=['label'],axis=1).values
    y=all_formants['label'].values

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 104.76it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 138.24it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 201.49it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 157.46it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 244.00it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 204.34it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 190.86it/s]

# %%
np.random.seed(seed)

# %%
model_v=Sequential()
#model_v.add(Dense(128, activation='relu', input_shape=(6,)))
#model_v.add(Dense(64, activation='relu'))
model_v.add(Dense(32, activation='tanh',input_shape=(X_train.shape[1],)))
model_v.add(Dense(16, activation='tanh'))
model_v.add(Dense(7, activation='softmax'))

# %%
model_v.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    #metrics=['AUC'],
    #metrics=['accuracy']#,
    metrics=[['accuracy','AUC']]
)

# %%
history_v=model_v.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From /home/rakibul/anaconda3/envs/speech_recog/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 1/1 [==============================] - 1s 1s/step - loss: 2.0888 - accuracy: 0.1682 - auc: 0.5213 - val_loss: 1.9973 - val_accuracy: 0.2072 - val_auc: 0.5394
# Epoch 2/50
# 1/1 [==============================] - 0s 380ms/step - loss: 1.9990 - accuracy: 0.2044 - auc: 0.5376 - val_loss: 1.9316 - val_accuracy: 0.1860 - val_auc: 0.5644
# Epoch 3/50
# 1/1 [==============================] - 0s 158ms/step - loss: 1.9325 - accuracy: 0.1815 - auc: 0.5630 - val_loss: 1.9036 - val_accuracy: 0.1765 - val_auc: 0.6092
# Epoch 4/50
# 1/1 [==============================] - 0s 182ms/step - loss: 1.9013 - accuracy: 0.1823 - auc: 0.6115 - val_loss: 1.9039 - val_accuracy: 0.2309 - val_auc: 0.6046
# Epoch 5/50
# 1/1 [==============================] - 0s 226ms/step - loss: 1.9065 - accuracy: 0.2330 - auc: 0.6013 - val_loss: 1.9087 - val_accuracy: 0.2164 - val_auc: 0.5978
# Epoch 6/50
# 1/1 [==============================] - 0s 221ms/step - loss: 1.9144 - accuracy: 0.2165 - auc: 0.5919 - val_loss: 1.9093 - val_accuracy: 0.2309 - val_auc: 0.5977
# Epoch 7/50
# 1/1 [==============================] - 0s 223ms/step - loss: 1.9115 - accuracy: 0.2311 - auc: 0.5948 - val_loss: 1.8920 - val_accuracy: 0.2361 - val_auc: 0.6106
# Epoch 8/50
# 1/1 [==============================] - 0s 211ms/step - loss: 1.8956 - accuracy: 0.2328 - auc: 0.6063 - val_loss: 1.8704 - val_accuracy: 0.2121 - val_auc: 0.6283
# Epoch 9/50
# 1/1 [==============================] - 0s 247ms/step - loss: 1.8712 - accuracy: 0.2101 - auc: 0.6261 - val_loss: 1.8434 - val_accuracy: 0.2287 - val_auc: 0.6672
# Epoch 10/50
# 1/1 [==============================] - 0s 187ms/step - loss: 1.8471 - accuracy: 0.2328 - auc: 0.6612 - val_loss: 1.8320 - val_accuracy: 0.2365 - val_auc: 0.6800
# Epoch 11/50
# 1/1 [==============================] - 0s 217ms/step - loss: 1.8324 - accuracy: 0.2403 - auc: 0.6773 - val_loss: 1.8270 - val_accuracy: 0.2541 - val_auc: 0.6797
# Epoch 12/50
# 1/1 [==============================] - 0s 212ms/step - loss: 1.8265 - accuracy: 0.2558 - auc: 0.6776 - val_loss: 1.8184 - val_accuracy: 0.2510 - val_auc: 0.6850
# Epoch 13/50
# 1/1 [==============================] - 0s 180ms/step - loss: 1.8183 - accuracy: 0.2512 - auc: 0.6837 - val_loss: 1.8082 - val_accuracy: 0.2633 - val_auc: 0.6869
# Epoch 14/50
# 1/1 [==============================] - 0s 176ms/step - loss: 1.8083 - accuracy: 0.2650 - auc: 0.6848 - val_loss: 1.7960 - val_accuracy: 0.2464 - val_auc: 0.6891
# Epoch 15/50
# 1/1 [==============================] - 0s 220ms/step - loss: 1.7920 - accuracy: 0.2475 - auc: 0.6908 - val_loss: 1.7827 - val_accuracy: 0.2411 - val_auc: 0.6961
# Epoch 16/50
# 1/1 [==============================] - 0s 195ms/step - loss: 1.7781 - accuracy: 0.2447 - auc: 0.6977 - val_loss: 1.7685 - val_accuracy: 0.2464 - val_auc: 0.7042
# Epoch 17/50
# 1/1 [==============================] - 0s 139ms/step - loss: 1.7636 - accuracy: 0.2506 - auc: 0.7059 - val_loss: 1.7544 - val_accuracy: 0.2566 - val_auc: 0.7123
# Epoch 18/50
# 1/1 [==============================] - 0s 222ms/step - loss: 1.7511 - accuracy: 0.2583 - auc: 0.7126 - val_loss: 1.7438 - val_accuracy: 0.2633 - val_auc: 0.7154
# Epoch 19/50
# 1/1 [==============================] - 0s 175ms/step - loss: 1.7386 - accuracy: 0.2642 - auc: 0.7173 - val_loss: 1.7278 - val_accuracy: 0.2834 - val_auc: 0.7244
# Epoch 20/50
# 1/1 [==============================] - 0s 198ms/step - loss: 1.7266 - accuracy: 0.2859 - auc: 0.7240 - val_loss: 1.7236 - val_accuracy: 0.2796 - val_auc: 0.7241
# Epoch 21/50
# 1/1 [==============================] - 0s 175ms/step - loss: 1.7211 - accuracy: 0.2818 - auc: 0.7255 - val_loss: 1.7123 - val_accuracy: 0.2887 - val_auc: 0.7280
# Epoch 22/50
# 1/1 [==============================] - 0s 242ms/step - loss: 1.7113 - accuracy: 0.2960 - auc: 0.7290 - val_loss: 1.7023 - val_accuracy: 0.2912 - val_auc: 0.7322
# Epoch 23/50
# 1/1 [==============================] - 0s 230ms/step - loss: 1.7017 - accuracy: 0.3001 - auc: 0.7332 - val_loss: 1.6914 - val_accuracy: 0.2983 - val_auc: 0.7357
# Epoch 24/50
# 1/1 [==============================] - 0s 162ms/step - loss: 1.6926 - accuracy: 0.3008 - auc: 0.7348 - val_loss: 1.6819 - val_accuracy: 0.3007 - val_auc: 0.7379
# Epoch 25/50
# 1/1 [==============================] - 0s 206ms/step - loss: 1.6840 - accuracy: 0.3041 - auc: 0.7363 - val_loss: 1.6759 - val_accuracy: 0.2979 - val_auc: 0.7391
# Epoch 26/50
# 1/1 [==============================] - 0s 142ms/step - loss: 1.6761 - accuracy: 0.3023 - auc: 0.7389 - val_loss: 1.6715 - val_accuracy: 0.2947 - val_auc: 0.7402
# Epoch 27/50
# 1/1 [==============================] - 0s 129ms/step - loss: 1.6696 - accuracy: 0.2981 - auc: 0.7403 - val_loss: 1.6637 - val_accuracy: 0.2919 - val_auc: 0.7422
# Epoch 28/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.6650 - accuracy: 0.2886 - auc: 0.7402 - val_loss: 1.6638 - val_accuracy: 0.2633 - val_auc: 0.7383
# Epoch 29/50
# 1/1 [==============================] - 0s 119ms/step - loss: 1.6623 - accuracy: 0.2694 - auc: 0.7380 - val_loss: 1.6574 - val_accuracy: 0.2534 - val_auc: 0.7415
# Epoch 30/50
# 1/1 [==============================] - 0s 116ms/step - loss: 1.6560 - accuracy: 0.2581 - auc: 0.7409 - val_loss: 1.6420 - val_accuracy: 0.2743 - val_auc: 0.7476
# Epoch 31/50
# 1/1 [==============================] - 0s 112ms/step - loss: 1.6460 - accuracy: 0.2742 - auc: 0.7442 - val_loss: 1.6387 - val_accuracy: 0.2887 - val_auc: 0.7498
# Epoch 32/50
# 1/1 [==============================] - 0s 142ms/step - loss: 1.6407 - accuracy: 0.2841 - auc: 0.7476 - val_loss: 1.6359 - val_accuracy: 0.2884 - val_auc: 0.7524
# Epoch 33/50
# 1/1 [==============================] - 0s 104ms/step - loss: 1.6412 - accuracy: 0.2813 - auc: 0.7489 - val_loss: 1.6386 - val_accuracy: 0.2877 - val_auc: 0.7524
# Epoch 34/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.6432 - accuracy: 0.2804 - auc: 0.7498 - val_loss: 1.6340 - val_accuracy: 0.3194 - val_auc: 0.7549
# Epoch 35/50
# 1/1 [==============================] - 0s 143ms/step - loss: 1.6371 - accuracy: 0.3178 - auc: 0.7527 - val_loss: 1.6241 - val_accuracy: 0.3237 - val_auc: 0.7586
# Epoch 36/50
# 1/1 [==============================] - 0s 176ms/step - loss: 1.6275 - accuracy: 0.3236 - auc: 0.7564 - val_loss: 1.6196 - val_accuracy: 0.3050 - val_auc: 0.7589
# Epoch 37/50
# 1/1 [==============================] - 0s 128ms/step - loss: 1.6223 - accuracy: 0.3139 - auc: 0.7581 - val_loss: 1.6185 - val_accuracy: 0.3064 - val_auc: 0.7585
# Epoch 38/50
# 1/1 [==============================] - 0s 80ms/step - loss: 1.6192 - accuracy: 0.3158 - auc: 0.7586 - val_loss: 1.6123 - val_accuracy: 0.3071 - val_auc: 0.7593
# Epoch 39/50
# 1/1 [==============================] - 0s 77ms/step - loss: 1.6179 - accuracy: 0.3157 - auc: 0.7579 - val_loss: 1.6079 - val_accuracy: 0.3096 - val_auc: 0.7605
# Epoch 40/50
# 1/1 [==============================] - 0s 110ms/step - loss: 1.6119 - accuracy: 0.3175 - auc: 0.7600 - val_loss: 1.6026 - val_accuracy: 0.3060 - val_auc: 0.7641
# Epoch 41/50
# 1/1 [==============================] - 0s 100ms/step - loss: 1.6079 - accuracy: 0.3076 - auc: 0.7622 - val_loss: 1.5972 - val_accuracy: 0.3103 - val_auc: 0.7665
# Epoch 42/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.6011 - accuracy: 0.3070 - auc: 0.7647 - val_loss: 1.5913 - val_accuracy: 0.3078 - val_auc: 0.7691
# Epoch 43/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.5958 - accuracy: 0.3046 - auc: 0.7673 - val_loss: 1.5916 - val_accuracy: 0.3339 - val_auc: 0.7704
# Epoch 44/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.5962 - accuracy: 0.3307 - auc: 0.7687 - val_loss: 1.5870 - val_accuracy: 0.3244 - val_auc: 0.7691
# Epoch 45/50
# 1/1 [==============================] - 0s 99ms/step - loss: 1.5947 - accuracy: 0.3231 - auc: 0.7661 - val_loss: 1.5825 - val_accuracy: 0.3177 - val_auc: 0.7684
# Epoch 46/50
# 1/1 [==============================] - 0s 117ms/step - loss: 1.5907 - accuracy: 0.3170 - auc: 0.7660 - val_loss: 1.5790 - val_accuracy: 0.3159 - val_auc: 0.7700
# Epoch 47/50
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5867 - accuracy: 0.3114 - auc: 0.7666 - val_loss: 1.5756 - val_accuracy: 0.3152 - val_auc: 0.7700
# Epoch 48/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.5817 - accuracy: 0.3158 - auc: 0.7676 - val_loss: 1.5755 - val_accuracy: 0.3184 - val_auc: 0.7702
# Epoch 49/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.5804 - accuracy: 0.3126 - auc: 0.7685 - val_loss: 1.5786 - val_accuracy: 0.3216 - val_auc: 0.7686
# Epoch 50/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.5832 - accuracy: 0.3173 - auc: 0.7668 - val_loss: 1.5748 - val_accuracy: 0.3039 - val_auc: 0.7696

# %%
e=shap.DeepExplainer(model_v,X_test)

# %%
shape_values=e.shap_values(X_test)

# %%
shap.summary_plot(shape_values,X_test)

# %%
model_v.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 32)                352
# _________________________________________________________________
# dense_43 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_44 (Dense)             (None, 7)                 119
# =================================================================
# Total params: 999
# Trainable params: 999
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_dict=history_v.history

loss_v=history_dict['loss']
val_loss_v=history_dict['val_loss']

epochs=range(1,len(loss_v)+1)

acc_v=history_dict['accuracy']
val_acc_v=history_dict['val_accuracy']

auc_v=history_dict['auc']
val_auc_v=history_dict['val_auc']

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'bo',label='Training loss')
plt.plot(epochs,val_loss_v,'b',label='Validation loss')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_vowel_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'bo',label='Training acc')
plt.plot(epochs,val_acc_v,'b',label='Validation acc')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_vowel_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_v,'bo',label='Training AUC')
plt.plot(epochs,val_auc_v,'b',label='Validation AUC')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/AUC_vowel_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
DATA_PATH="./Word_Data/Formant/"

# %%
def get_formant(file_path):
    formant=pd.read_csv(file_path,
                delim_whitespace=True,
                header=None,
                names=["time","F1","F2","F3","F4","F5"],
                dtype=np.float64,
                na_values="--undefined--")
    return formant

def get_all_formants(path=DATA_PATH):
    labels=labels=sorted(os.listdir(path))
    all_formant=pd.DataFrame() #empty dataframe to store all_formants
    
    for label_index,label in enumerate(labels):
        folder_formant=pd.DataFrame() #empty dataframe to store formants of indivuals vowels/words i.e. folders

        formant_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(formant_files,"Reading Formants of label -'{}'".format(label)):
            #print(file)
            individual_formant=get_formant(file_path=file)
            folder_formant=folder_formant.append(individual_formant,ignore_index=True)
        
        folder_formant['label']=label_index  #new columns for encoding label
        
        all_formant=all_formant.append(folder_formant,ignore_index=True)
        
    return all_formant

def get_train_test(split_ratio=0.8,random_state=42):
    all_formants=get_all_formants()
    
    all_formants['disp(F5-F1)']=all_formants['F5']-all_formants['F1']
    all_formants['disp(F4-F3)']=all_formants['F4']-all_formants['F3']
    all_formants['disp(F5-F3)']=all_formants['F5']-all_formants['F3']
    all_formants['disp(F5-F4)']=all_formants['F5']-all_formants['F4']    
    
    X=all_formants.drop(labels=['label'],axis=1).values
    y=all_formants['label'].values

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
np.random.seed(seed)
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Formants of label -'Formant1': 100%|██████████| 40/40 [00:00<00:00, 443.46it/s]
# Reading Formants of label -'Formant2': 100%|██████████| 40/40 [00:00<00:00, 477.99it/s]
# Reading Formants of label -'Formant3': 100%|██████████| 40/40 [00:00<00:00, 436.92it/s]
# Reading Formants of label -'Formant4': 100%|██████████| 40/40 [00:00<00:00, 278.27it/s]
# Reading Formants of label -'Formant5': 100%|██████████| 40/40 [00:00<00:00, 450.82it/s]
# Reading Formants of label -'Formant6': 100%|██████████| 40/40 [00:00<00:00, 462.90it/s]
# Reading Formants of label -'Formant7': 100%|██████████| 40/40 [00:00<00:00, 330.01it/s]

# %%
model_w=Sequential()
#model_w.add(Dense(128, activation='tanh', input_shape=(6,)))
#model_w.add(Dense(64, activation='tanh'))
model_w.add(Dense(32, activation='tanh',input_shape=(X_train.shape[1],)))
model_w.add(Dense(16, activation='tanh'))
model_w.add(Dense(7, activation='softmax'))

# %%
model_w.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    #metrics=['AUC'],
    #metrics=['accuracy']#,
    metrics=[['accuracy','AUC']]
)

# %%
history_w=model_w.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 547ms/step - loss: 2.0687 - accuracy: 0.1492 - auc: 0.5154 - val_loss: 1.9982 - val_accuracy: 0.1844 - val_auc: 0.5263
# Epoch 2/50
# 1/1 [==============================] - 0s 141ms/step - loss: 1.9899 - accuracy: 0.1930 - auc: 0.5329 - val_loss: 1.9570 - val_accuracy: 0.2242 - val_auc: 0.5467
# Epoch 3/50
# 1/1 [==============================] - 0s 180ms/step - loss: 1.9487 - accuracy: 0.2294 - auc: 0.5544 - val_loss: 1.9431 - val_accuracy: 0.2476 - val_auc: 0.5537
# Epoch 4/50
# 1/1 [==============================] - 0s 120ms/step - loss: 1.9361 - accuracy: 0.2511 - auc: 0.5598 - val_loss: 1.9334 - val_accuracy: 0.2397 - val_auc: 0.5607
# Epoch 5/50
# 1/1 [==============================] - 0s 97ms/step - loss: 1.9271 - accuracy: 0.2431 - auc: 0.5663 - val_loss: 1.9184 - val_accuracy: 0.2392 - val_auc: 0.5744
# Epoch 6/50
# 1/1 [==============================] - 0s 138ms/step - loss: 1.9128 - accuracy: 0.2415 - auc: 0.5797 - val_loss: 1.9018 - val_accuracy: 0.2511 - val_auc: 0.5891
# Epoch 7/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.8962 - accuracy: 0.2535 - auc: 0.5941 - val_loss: 1.8886 - val_accuracy: 0.2438 - val_auc: 0.6082
# Epoch 8/50
# 1/1 [==============================] - 0s 100ms/step - loss: 1.8825 - accuracy: 0.2473 - auc: 0.6151 - val_loss: 1.8767 - val_accuracy: 0.2174 - val_auc: 0.6206
# Epoch 9/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.8727 - accuracy: 0.2222 - auc: 0.6248 - val_loss: 1.8695 - val_accuracy: 0.2285 - val_auc: 0.6276
# Epoch 10/50
# 1/1 [==============================] - 0s 107ms/step - loss: 1.8674 - accuracy: 0.2259 - auc: 0.6290 - val_loss: 1.8685 - val_accuracy: 0.2214 - val_auc: 0.6260
# Epoch 11/50
# 1/1 [==============================] - 0s 125ms/step - loss: 1.8662 - accuracy: 0.2159 - auc: 0.6288 - val_loss: 1.8723 - val_accuracy: 0.2483 - val_auc: 0.6235
# Epoch 12/50
# 1/1 [==============================] - 0s 142ms/step - loss: 1.8695 - accuracy: 0.2540 - auc: 0.6266 - val_loss: 1.8701 - val_accuracy: 0.2494 - val_auc: 0.6259
# Epoch 13/50
# 1/1 [==============================] - 0s 135ms/step - loss: 1.8682 - accuracy: 0.2547 - auc: 0.6281 - val_loss: 1.8664 - val_accuracy: 0.2499 - val_auc: 0.6295
# Epoch 14/50
# 1/1 [==============================] - 0s 113ms/step - loss: 1.8628 - accuracy: 0.2555 - auc: 0.6331 - val_loss: 1.8589 - val_accuracy: 0.2501 - val_auc: 0.6380
# Epoch 15/50
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8548 - accuracy: 0.2565 - auc: 0.6415 - val_loss: 1.8529 - val_accuracy: 0.2542 - val_auc: 0.6433
# Epoch 16/50
# 1/1 [==============================] - 0s 129ms/step - loss: 1.8492 - accuracy: 0.2557 - auc: 0.6464 - val_loss: 1.8462 - val_accuracy: 0.2390 - val_auc: 0.6491
# Epoch 17/50
# 1/1 [==============================] - 0s 163ms/step - loss: 1.8454 - accuracy: 0.2343 - auc: 0.6498 - val_loss: 1.8431 - val_accuracy: 0.2646 - val_auc: 0.6485
# Epoch 18/50
# 1/1 [==============================] - 0s 151ms/step - loss: 1.8412 - accuracy: 0.2626 - auc: 0.6499 - val_loss: 1.8430 - val_accuracy: 0.2603 - val_auc: 0.6469
# Epoch 19/50
# 1/1 [==============================] - 0s 209ms/step - loss: 1.8389 - accuracy: 0.2584 - auc: 0.6503 - val_loss: 1.8400 - val_accuracy: 0.2593 - val_auc: 0.6469
# Epoch 20/50
# 1/1 [==============================] - 0s 236ms/step - loss: 1.8354 - accuracy: 0.2615 - auc: 0.6515 - val_loss: 1.8345 - val_accuracy: 0.2598 - val_auc: 0.6479
# Epoch 21/50
# 1/1 [==============================] - 0s 150ms/step - loss: 1.8272 - accuracy: 0.2624 - auc: 0.6549 - val_loss: 1.8279 - val_accuracy: 0.2654 - val_auc: 0.6517
# Epoch 22/50
# 1/1 [==============================] - 0s 146ms/step - loss: 1.8189 - accuracy: 0.2676 - auc: 0.6593 - val_loss: 1.8208 - val_accuracy: 0.2628 - val_auc: 0.6560
# Epoch 23/50
# 1/1 [==============================] - 0s 184ms/step - loss: 1.8142 - accuracy: 0.2633 - auc: 0.6611 - val_loss: 1.8186 - val_accuracy: 0.2649 - val_auc: 0.6581
# Epoch 24/50
# 1/1 [==============================] - 0s 146ms/step - loss: 1.8164 - accuracy: 0.2612 - auc: 0.6611 - val_loss: 1.8168 - val_accuracy: 0.2641 - val_auc: 0.6617
# Epoch 25/50
# 1/1 [==============================] - 0s 138ms/step - loss: 1.8191 - accuracy: 0.2602 - auc: 0.6597 - val_loss: 1.8147 - val_accuracy: 0.2638 - val_auc: 0.6608
# Epoch 26/50
# 1/1 [==============================] - 0s 167ms/step - loss: 1.8175 - accuracy: 0.2603 - auc: 0.6590 - val_loss: 1.8097 - val_accuracy: 0.2649 - val_auc: 0.6635
# Epoch 27/50
# 1/1 [==============================] - 0s 155ms/step - loss: 1.8121 - accuracy: 0.2616 - auc: 0.6614 - val_loss: 1.8051 - val_accuracy: 0.2666 - val_auc: 0.6648
# Epoch 28/50
# 1/1 [==============================] - 0s 162ms/step - loss: 1.8062 - accuracy: 0.2625 - auc: 0.6634 - val_loss: 1.8017 - val_accuracy: 0.2671 - val_auc: 0.6635
# Epoch 29/50
# 1/1 [==============================] - 0s 141ms/step - loss: 1.7972 - accuracy: 0.2650 - auc: 0.6680 - val_loss: 1.7979 - val_accuracy: 0.2720 - val_auc: 0.6677
# Epoch 30/50
# 1/1 [==============================] - 0s 125ms/step - loss: 1.7925 - accuracy: 0.2737 - auc: 0.6720 - val_loss: 1.7995 - val_accuracy: 0.2694 - val_auc: 0.6671
# Epoch 31/50
# 1/1 [==============================] - 0s 198ms/step - loss: 1.7926 - accuracy: 0.2744 - auc: 0.6723 - val_loss: 1.7969 - val_accuracy: 0.2753 - val_auc: 0.6696
# Epoch 32/50
# 1/1 [==============================] - 0s 110ms/step - loss: 1.7897 - accuracy: 0.2800 - auc: 0.6749 - val_loss: 1.7921 - val_accuracy: 0.2770 - val_auc: 0.6728
# Epoch 33/50
# 1/1 [==============================] - 0s 189ms/step - loss: 1.7862 - accuracy: 0.2804 - auc: 0.6773 - val_loss: 1.7915 - val_accuracy: 0.2760 - val_auc: 0.6743
# Epoch 34/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.7852 - accuracy: 0.2787 - auc: 0.6785 - val_loss: 1.7885 - val_accuracy: 0.2745 - val_auc: 0.6762
# Epoch 35/50
# 1/1 [==============================] - 0s 148ms/step - loss: 1.7815 - accuracy: 0.2784 - auc: 0.6809 - val_loss: 1.7840 - val_accuracy: 0.2753 - val_auc: 0.6756
# Epoch 36/50
# 1/1 [==============================] - 0s 114ms/step - loss: 1.7777 - accuracy: 0.2774 - auc: 0.6802 - val_loss: 1.7794 - val_accuracy: 0.2946 - val_auc: 0.6787
# Epoch 37/50
# 1/1 [==============================] - 0s 115ms/step - loss: 1.7741 - accuracy: 0.2993 - auc: 0.6828 - val_loss: 1.7753 - val_accuracy: 0.2943 - val_auc: 0.6793
# Epoch 38/50
# 1/1 [==============================] - 0s 100ms/step - loss: 1.7734 - accuracy: 0.2956 - auc: 0.6813 - val_loss: 1.7748 - val_accuracy: 0.2941 - val_auc: 0.6795
# Epoch 39/50
# 1/1 [==============================] - 0s 125ms/step - loss: 1.7715 - accuracy: 0.2956 - auc: 0.6816 - val_loss: 1.7743 - val_accuracy: 0.2946 - val_auc: 0.6775
# Epoch 40/50
# 1/1 [==============================] - 0s 221ms/step - loss: 1.7695 - accuracy: 0.2961 - auc: 0.6807 - val_loss: 1.7740 - val_accuracy: 0.2941 - val_auc: 0.6772
# Epoch 41/50
# 1/1 [==============================] - 0s 128ms/step - loss: 1.7677 - accuracy: 0.2970 - auc: 0.6815 - val_loss: 1.7722 - val_accuracy: 0.2946 - val_auc: 0.6789
# Epoch 42/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.7653 - accuracy: 0.2977 - auc: 0.6836 - val_loss: 1.7693 - val_accuracy: 0.2951 - val_auc: 0.6822
# Epoch 43/50
# 1/1 [==============================] - 0s 107ms/step - loss: 1.7625 - accuracy: 0.2979 - auc: 0.6864 - val_loss: 1.7678 - val_accuracy: 0.2908 - val_auc: 0.6828
# Epoch 44/50
# 1/1 [==============================] - 0s 156ms/step - loss: 1.7607 - accuracy: 0.2977 - auc: 0.6868 - val_loss: 1.7656 - val_accuracy: 0.2910 - val_auc: 0.6855
# Epoch 45/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.7598 - accuracy: 0.2981 - auc: 0.6890 - val_loss: 1.7632 - val_accuracy: 0.2951 - val_auc: 0.6870
# Epoch 46/50
# 1/1 [==============================] - 0s 113ms/step - loss: 1.7580 - accuracy: 0.3000 - auc: 0.6903 - val_loss: 1.7647 - val_accuracy: 0.2953 - val_auc: 0.6870
# Epoch 47/50
# 1/1 [==============================] - 0s 143ms/step - loss: 1.7580 - accuracy: 0.3005 - auc: 0.6910 - val_loss: 1.7629 - val_accuracy: 0.2948 - val_auc: 0.6878
# Epoch 48/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.7562 - accuracy: 0.3017 - auc: 0.6919 - val_loss: 1.7609 - val_accuracy: 0.2956 - val_auc: 0.6892
# Epoch 49/50
# 1/1 [==============================] - 0s 108ms/step - loss: 1.7584 - accuracy: 0.2996 - auc: 0.6909 - val_loss: 1.7595 - val_accuracy: 0.2956 - val_auc: 0.6902
# Epoch 50/50
# 1/1 [==============================] - 0s 106ms/step - loss: 1.7572 - accuracy: 0.3000 - auc: 0.6922 - val_loss: 1.7579 - val_accuracy: 0.3019 - val_auc: 0.6919

# %%
history_dict=history_w.history
loss_w=history_dict['loss']
val_loss_w=history_dict['val_loss']

epochs=range(1,len(loss_v)+1)

acc_w=history_dict['accuracy']
val_acc_w=history_dict['val_accuracy']

auc_w=history_dict['auc']
val_auc_w=history_dict['val_auc']

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_w,'bo',label='Training loss')
plt.plot(epochs,val_loss_w,'b',label='Validation loss')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_word_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_w,'bo',label='Training acc')
plt.plot(epochs,val_acc_w,'b',label='Validation acc')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_word_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_w,'bo',label='Training AUC')
plt.plot(epochs,val_auc_w,'b',label='Validation AUC')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/AUC_word_'+save_specifier+'.svg',format='svg', dpi=600)

# %%
#COMPARE

# %%
epochs=range(1,len(loss_v)+1)

# %%
save_specifier='fromant_disp_32_16_tanh_softmax_adam_0.005_batchfull_adding_input_shape'

# %%
#sns.reset()
#sns.reset_orig()
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'r',label='Vowel')
plt.plot(epochs,loss_w,'b',label='Word')
plt.title('Loss comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/loss_compare_'+save_specifier+'.svg',format='svg',dpi=600)
#plt.savefig('./Result/New_without_CNN/loss_compare_'+save_specifier+'.eps',format='eps',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'r',label='Vowel')
plt.plot(epochs,acc_w,'b',label='Word')
plt.title('Accuracy comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/accuracy_compate_'+save_specifier+'.svg',format='svg',dpi=600)
#plt.savefig('./Result/New_without_CNN/accuracy_compate_'+save_specifier+'.eps',format='eps',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_v,'r',label='Vowel')
plt.plot(epochs,auc_w,'b',label='Word')
plt.title('AUC comparison')
plt.xticks(epochs)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
#plt.savefig('./Result/New_without_CNN/AUC_compate_'+save_specifier+'.svg',format='svg',dpi=600)
#plt.savefig('./Result/New_without_CNN/AUC_compate_'+save_specifier+'.eps',format='eps',dpi=600)

# %%
all_compare_df=pd.DataFrame({'loss_v':loss_v,
                      'val_loss_v':val_loss_v,
                      'acc_v':acc_v,
                      'val_acc_v':val_acc_v,
                      'auc_v':auc_v,
                      'val_auc_v':val_auc_v,
                      'loss_w':loss_w,
                      'val_loss_w':val_loss_w,
                      'acc_w':acc_w,
                      'val_acc_w':val_acc_w,
                      'auc_w':auc_w,
                      'val_auc_w':val_auc_w
                     })

all_compare_df.to_csv('./Result/New_without_CNN/all_compare_data_'+save_specifier+'.csv')

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  1.510234    1.498732  0.366437   0.370279  0.796772   0.800146  1.708708
# 46  1.504479    1.498546  0.365201   0.367102  0.797813   0.798793  1.707437
# 47  1.500465    1.493217  0.364848   0.376633  0.798146   0.801928  1.706840
# 48  1.497878    1.487364  0.368114   0.381221  0.799064   0.803229  1.704514
# 49  1.493867    1.477454  0.372881   0.384045  0.799755   0.805838  1.703115
#
#     val_loss_w     acc_w  val_acc_w     auc_w  val_auc_w
# 45    1.714930  0.303956   0.299898  0.720853   0.715563
# 46    1.713586  0.305353   0.300660  0.721409   0.716229
# 47    1.713536  0.305924   0.298121  0.721904   0.715366
# 48    1.714414  0.304591   0.297613  0.721866   0.713816
# 49    1.715560  0.304019   0.295328  0.721080   0.712323

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  1.411883    1.405710  0.447034   0.461701  0.833349   0.836040  1.781247
# 46  1.397944    1.405708  0.465660   0.461701  0.838839   0.836425  1.781183
# 47  1.398288    1.398337  0.465749   0.469820  0.838970   0.838291  1.782951
# 48  1.396289    1.386209  0.470251   0.492411  0.839035   0.842212  1.780074
# 49  1.383023    1.377770  0.486405   0.498412  0.843179   0.843809  1.774793
#
#     val_loss_w     acc_w  val_acc_w     auc_w  val_auc_w
# 45    1.795952  0.276208   0.262062  0.681543   0.670234
# 46    1.794109  0.273224   0.264093  0.679729   0.671856
# 47    1.789811  0.272017   0.279584  0.678212   0.675529
# 48    1.782680  0.288463   0.283647  0.680309   0.680218
# 49    1.775333  0.290939   0.297359  0.684268   0.684437

# %%
np.random.seed(seed)

# %%
np.random.rand()
# Out:
# 0.7151893663724195

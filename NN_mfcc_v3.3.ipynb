# %%
import os,librosa
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers as opt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses
import pandas as pd
import seaborn as sns

# %%
seed=15
n_MFCC=13
column_names= ['MFCC_'+str(i) for i in range(1,n_MFCC+1)]

# %%
DATA_PATH="./Vowel_Data/Vowel/"

# %%
def get_mfcc(file_path):
    wave, sr= librosa.load(file_path, mono=True, sr=None)
    mfcc=librosa.feature.mfcc(wave,sr=sr,n_mfcc=n_MFCC)
    mfcc_df=pd.DataFrame(mfcc.T,columns=column_names) #convert array to pandas df
    return mfcc_df

def get_all_mfcc(path=DATA_PATH):
    labels=sorted(os.listdir(path))
    all_mfcc=pd.DataFrame() #empty dataframe to store all_mfccs
    
    for label_index,label in enumerate(labels):
        folder_mfcc=pd.DataFrame() #empty dataframe to store mfcc of indivuals vowels/words i.e. folders

        speech_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(speech_files,"Reading Speech of label -'{}'".format(label)):
            #print(file)
            individual_mfcc=get_mfcc(file_path=file)
            folder_mfcc=folder_mfcc.append(individual_mfcc,ignore_index=True)
        
        folder_mfcc['label']=label_index  #new columns for encoding label
        
        all_mfcc=all_mfcc.append(folder_mfcc,ignore_index=True)
        
    return all_mfcc

def get_train_test(split_ratio=0.8,random_state=42):
    all_mfccs=get_all_mfcc()
    
    y=all_mfccs['label'].values
    
    only_mfcc=all_mfccs.drop(labels=['label'],axis=1)
    standard_mfcc=(only_mfcc-only_mfcc.mean())/only_mfcc.std()
    X=standard_mfcc.values

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Speech of label -'vowel1': 100%|██████████| 40/40 [00:00<00:00, 60.89it/s]
# Reading Speech of label -'vowel2': 100%|██████████| 40/40 [00:00<00:00, 92.48it/s]
# Reading Speech of label -'vowel3': 100%|██████████| 40/40 [00:00<00:00, 110.59it/s]
# Reading Speech of label -'vowel4': 100%|██████████| 40/40 [00:00<00:00, 117.09it/s]
# Reading Speech of label -'vowel5': 100%|██████████| 40/40 [00:00<00:00, 109.01it/s]
# Reading Speech of label -'vowel6': 100%|██████████| 40/40 [00:00<00:00, 111.28it/s]
# Reading Speech of label -'vowel7': 100%|██████████| 40/40 [00:00<00:00, 101.74it/s]

# %%
np.random.seed(seed)
model_v=Sequential()
#model_v.add(Dense(128, activation='relu', input_shape=(6,)))
#model_v.add(Dense(64, activation='relu'))
model_v.add(Dense(32, activation='tanh',input_shape=(X_train.shape[1],)))
model_v.add(Dense(16, activation='tanh'))
model_v.add(Dense(7, activation='softmax'))

# %%
model_v.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    #metrics=['AUC'],
    #metrics=['accuracy']#,
    metrics=[['accuracy','AUC']]
)

# %%
history_v=model_v.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From /home/rakibul/anaconda3/envs/speech_recog/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 1/1 [==============================] - 0s 351ms/step - loss: 1.9895 - accuracy: 0.1545 - auc: 0.5531 - val_loss: 1.9014 - val_accuracy: 0.2063 - val_auc: 0.6090
# Epoch 2/50
# 1/1 [==============================] - 0s 73ms/step - loss: 1.8899 - accuracy: 0.2061 - auc: 0.6174 - val_loss: 1.8091 - val_accuracy: 0.2616 - val_auc: 0.6714
# Epoch 3/50
# 1/1 [==============================] - 0s 93ms/step - loss: 1.8000 - accuracy: 0.2696 - auc: 0.6779 - val_loss: 1.7261 - val_accuracy: 0.3068 - val_auc: 0.7257
# Epoch 4/50
# 1/1 [==============================] - 0s 95ms/step - loss: 1.7189 - accuracy: 0.3168 - auc: 0.7301 - val_loss: 1.6516 - val_accuracy: 0.3500 - val_auc: 0.7698
# Epoch 5/50
# 1/1 [==============================] - 0s 83ms/step - loss: 1.6460 - accuracy: 0.3622 - auc: 0.7727 - val_loss: 1.5844 - val_accuracy: 0.3905 - val_auc: 0.8040
# Epoch 6/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.5801 - accuracy: 0.3979 - auc: 0.8056 - val_loss: 1.5237 - val_accuracy: 0.4221 - val_auc: 0.8300
# Epoch 7/50
# 1/1 [==============================] - 0s 87ms/step - loss: 1.5205 - accuracy: 0.4341 - auc: 0.8311 - val_loss: 1.4686 - val_accuracy: 0.4526 - val_auc: 0.8495
# Epoch 8/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.4663 - accuracy: 0.4594 - auc: 0.8505 - val_loss: 1.4184 - val_accuracy: 0.4853 - val_auc: 0.8648
# Epoch 9/50
# 1/1 [==============================] - 0s 79ms/step - loss: 1.4169 - accuracy: 0.4862 - auc: 0.8654 - val_loss: 1.3726 - val_accuracy: 0.5116 - val_auc: 0.8768
# Epoch 10/50
# 1/1 [==============================] - 0s 75ms/step - loss: 1.3716 - accuracy: 0.5135 - auc: 0.8774 - val_loss: 1.3306 - val_accuracy: 0.5384 - val_auc: 0.8865
# Epoch 11/50
# 1/1 [==============================] - 0s 100ms/step - loss: 1.3301 - accuracy: 0.5440 - auc: 0.8870 - val_loss: 1.2919 - val_accuracy: 0.5647 - val_auc: 0.8947
# Epoch 12/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.2918 - accuracy: 0.5731 - auc: 0.8950 - val_loss: 1.2562 - val_accuracy: 0.5821 - val_auc: 0.9017
# Epoch 13/50
# 1/1 [==============================] - 0s 75ms/step - loss: 1.2563 - accuracy: 0.5959 - auc: 0.9019 - val_loss: 1.2231 - val_accuracy: 0.6105 - val_auc: 0.9077
# Epoch 14/50
# 1/1 [==============================] - 0s 87ms/step - loss: 1.2234 - accuracy: 0.6130 - auc: 0.9078 - val_loss: 1.1923 - val_accuracy: 0.6268 - val_auc: 0.9130
# Epoch 15/50
# 1/1 [==============================] - 0s 85ms/step - loss: 1.1928 - accuracy: 0.6315 - auc: 0.9128 - val_loss: 1.1637 - val_accuracy: 0.6421 - val_auc: 0.9176
# Epoch 16/50
# 1/1 [==============================] - 0s 73ms/step - loss: 1.1644 - accuracy: 0.6485 - auc: 0.9171 - val_loss: 1.1371 - val_accuracy: 0.6468 - val_auc: 0.9214
# Epoch 17/50
# 1/1 [==============================] - 0s 88ms/step - loss: 1.1378 - accuracy: 0.6615 - auc: 0.9209 - val_loss: 1.1123 - val_accuracy: 0.6584 - val_auc: 0.9246
# Epoch 18/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.1131 - accuracy: 0.6711 - auc: 0.9240 - val_loss: 1.0890 - val_accuracy: 0.6637 - val_auc: 0.9274
# Epoch 19/50
# 1/1 [==============================] - 0s 72ms/step - loss: 1.0899 - accuracy: 0.6777 - auc: 0.9268 - val_loss: 1.0673 - val_accuracy: 0.6695 - val_auc: 0.9300
# Epoch 20/50
# 1/1 [==============================] - 0s 83ms/step - loss: 1.0682 - accuracy: 0.6843 - auc: 0.9293 - val_loss: 1.0468 - val_accuracy: 0.6721 - val_auc: 0.9323
# Epoch 21/50
# 1/1 [==============================] - 0s 85ms/step - loss: 1.0477 - accuracy: 0.6898 - auc: 0.9315 - val_loss: 1.0274 - val_accuracy: 0.6800 - val_auc: 0.9344
# Epoch 22/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1
50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7930 - accuracy: 0.7338 - auc: 0.9554 - val_loss: 0.7888 - val_accuracy: 0.7289 - val_auc: 0.9558
# Epoch 42/50
# 1/1 [==============================] - 0s 83ms/step - loss: 0.7849 - accuracy: 0.7346 - auc: 0.9561 - val_loss: 0.7815 - val_accuracy: 0.7300 - val_auc: 0.9564
# Epoch 43/50
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7772 - accuracy: 0.7369 - auc: 0.9568 - val_loss: 0.7745 - val_accuracy: 0.7337 - val_auc: 0.9570
# Epoch 44/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.7697 - accuracy: 0.7379 - auc: 0.9575 - val_loss: 0.7677 - val_accuracy: 0.7358 - val_auc: 0.9575
# Epoch 45/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.7625 - accuracy: 0.7384 - auc: 0.9581 - val_loss: 0.7611 - val_accuracy: 0.7384 - val_auc: 0.9581
# Epoch 46/50
# 1/1 [==============================] - 0s 93ms/step - loss: 0.7555 - accuracy: 0.7398 - auc: 0.9588 - val_loss: 0.7548 - val_accuracy: 0.7395 - val_auc: 0.9586
# Epoch 47/50
# 1/1 [==============================] - 0s 79ms/step - loss: 0.7488 - accuracy: 0.7414 - auc: 0.9594 - val_loss: 0.7487 - val_accuracy: 0.7405 - val_auc: 0.9592
# Epoch 48/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.7422 - accuracy: 0.7430 - auc: 0.9599 - val_loss: 0.7427 - val_accuracy: 0.7411 - val_auc: 0.9596
# Epoch 49/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.7359 - accuracy: 0.7455 - auc: 0.9605 - val_loss: 0.7370 - val_accuracy: 0.7437 - val_auc: 0.9601
# Epoch 50/50
# 1/1 [==============================] - 0s 91ms/step - loss: 0.7297 - accuracy: 0.7476 - auc: 0.9610 - val_loss: 0.7314 - val_accuracy: 0.7453 - val_auc: 0.9606

# %%
history_dict=history_v.history

loss_v=history_dict['loss']
val_loss_v=history_dict['val_loss']

epochs=range(1,len(loss_v)+1)

acc_v=history_dict['accuracy']
val_acc_v=history_dict['val_accuracy']

auc_v=history_dict['auc']
val_auc_v=history_dict['val_auc']

# %%
#plt.figure(figsize=(10,4))
ax=sns.lineplot(epochs,loss_v,label='Training loss',legend=False,color='m')
ax=sns.scatterplot(epochs,val_loss_v,label='Validation loss',legend=False,color='m')

ax2=ax.twinx()
ax2=sns.lineplot(epochs,auc_v,label='Training AUC',legend=False)
ax2=sns.scatterplot(epochs,val_auc_v,label='Validation AUC',legend=False)

ax.set_title('Vowel Classification')
ax.set(xlabel='Epochs', ylabel='Loss')
ax2.set(ylabel='AUC - ROC')

ax.figure.legend(loc=(0.6,0.4))
plt.tight_layout()
#plt.savefig('./New_without_CNN/loss_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
fig, ax=plt.subplots()
ln1=ax.plot(epochs,loss_v,'m', label='Training Loss')
ln2=ax.plot(epochs,val_loss_v,'mo', label='Validation Loss')

ax2=ax.twinx()
ln3=ax2.plot(epochs,auc_v,'b', label='Training AUC')
ln3=ax2.plot(epochs,val_auc_v,'bo', label='Validation AUC')

ax.set_title('Vowel Classification')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax2.set_ylabel('AUC - ROC')

plt.xticks(ticks)
ax.legend(loc=(0.6,0.2))
ax2.legend(loc=(0.6,0.7))
#fig.legend(loc=(0.6,0.4))
plt.tight_layout()
#plt.savefig('./New_without_CNN/loss_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
ticks=[1]
ticks2=[i for i in range(5,len(loss_v)+1,5)]

# %%
ticks.extend(ticks2)

# %%
#plt.figure(figsize=(10,4))
fig, ax=plt.subplots()
ax.plot(epochs,auc_v,'bo',label='Training acc')
ax.plot(epochs,val_auc_v,'b',label='Validation acc')
ax2=ax.twinx()
ax2.plot(epochs,loss_v,label='Training loss')
ax2.plot(epochs,val_loss_v,label='Val loss')
plt.xticks(ticks)
#plt.xticks(epochs,rotation=90)
ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.set_title('Vowel Classification')
ax2.set_ylabel('Loss')
fig.legend()
ax2.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/accuracy_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
#plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'bo',label='Training acc')
plt.plot(epochs,val_acc_v,'b',label='Validation acc')
plt.xticks([1, 50])
#plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Vowel Classification')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/accuracy_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_v,'bo',label='Training AUC')
plt.plot(epochs,val_auc_v,'b',label='Validation AUC')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Vowel Classification')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/AUC_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
DATA_PATH="./Word_Data/Word/"

# %%
def get_mfcc(file_path):
    wave, sr= librosa.load(file_path, mono=True, sr=None)
    mfcc=librosa.feature.mfcc(wave,sr=sr,n_mfcc=n_MFCC)
    mfcc_df=pd.DataFrame(mfcc.T,columns=column_names) #convert array to pandas df
    return mfcc_df

def get_all_mfcc(path=DATA_PATH):
    labels=sorted(os.listdir(path))
    all_mfcc=pd.DataFrame() #empty dataframe to store all_mfccs
    
    for label_index,label in enumerate(labels):
        folder_mfcc=pd.DataFrame() #empty dataframe to store mfcc of indivuals vowels/words i.e. folders

        speech_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(speech_files,"Reading Speech of label -'{}'".format(label)):
            #print(file)
            individual_mfcc=get_mfcc(file_path=file)
            folder_mfcc=folder_mfcc.append(individual_mfcc,ignore_index=True)
        
        folder_mfcc['label']=label_index  #new columns for encoding label
        
        all_mfcc=all_mfcc.append(folder_mfcc,ignore_index=True)
        
    return all_mfcc

def get_train_test(split_ratio=0.8,random_state=42):
    all_mfccs=get_all_mfcc()
    
    y=all_mfccs['label'].values
    
    only_mfcc=all_mfccs.drop(labels=['label'],axis=1)
    standard_mfcc=(only_mfcc-only_mfcc.mean())/only_mfcc.std()
    X=standard_mfcc.values

    assert X.shape[0] == len(y)
    return train_test_split(X,y,test_size=(1-split_ratio),random_state=random_state,shuffle=True,stratify=y)

# %%
X_train, X_test, y_train, y_test=get_train_test()
y_train_hot=to_categorical(y_train)
y_test_hot=to_categorical(y_test)
# Out:
# Reading Speech of label -'Word1': 100%|██████████| 40/40 [00:00<00:00, 47.19it/s]
# Reading Speech of label -'Word2': 100%|██████████| 40/40 [00:00<00:00, 46.52it/s]
# Reading Speech of label -'Word3': 100%|██████████| 40/40 [00:00<00:00, 97.41it/s]
# Reading Speech of label -'Word4': 100%|██████████| 40/40 [00:00<00:00, 105.98it/s]
# Reading Speech of label -'Word5': 100%|██████████| 40/40 [00:00<00:00, 92.23it/s]
# Reading Speech of label -'Word6': 100%|██████████| 40/40 [00:00<00:00, 107.12it/s]
# Reading Speech of label -'Word7': 100%|██████████| 40/40 [00:00<00:00, 111.37it/s]

# %%
np.random.seed(seed)
model_w=Sequential()
#model_w.add(Dense(128, activation='tanh', input_shape=(6,)))
#model_w.add(Dense(64, activation='tanh'))
model_w.add(Dense(32, activation='tanh',input_shape=(X_train.shape[1],)))
model_w.add(Dense(16, activation='tanh'))
model_w.add(Dense(7, activation='softmax'))

# %%
model_w.compile(
    #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
    optimizer=opt.Adam(learning_rate=0.005),
    #loss=losses.CategoricalCrossentropy(),
    loss='categorical_crossentropy',
    #metrics=['AUC'],
    #metrics=['accuracy']#,
    metrics=[['accuracy','AUC']]
)

# %%
history_w=model_w.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 321ms/step - loss: 2.1134 - accuracy: 0.1599 - auc: 0.4858 - val_loss: 2.0089 - val_accuracy: 0.1852 - val_auc: 0.5362
# Epoch 2/50
# 1/1 [==============================] - 0s 101ms/step - loss: 2.0249 - accuracy: 0.1800 - auc: 0.5265 - val_loss: 1.9282 - val_accuracy: 0.2221 - val_auc: 0.5882
# Epoch 3/50
# 1/1 [==============================] - 0s 102ms/step - loss: 1.9445 - accuracy: 0.2090 - auc: 0.5768 - val_loss: 1.8565 - val_accuracy: 0.2626 - val_auc: 0.6405
# Epoch 4/50
# 1/1 [==============================] - 0s 93ms/step - loss: 1.8731 - accuracy: 0.2496 - auc: 0.6281 - val_loss: 1.7946 - val_accuracy: 0.2959 - val_auc: 0.6827
# Epoch 5/50
# 1/1 [==============================] - 0s 93ms/step - loss: 1.8113 - accuracy: 0.2813 - auc: 0.6706 - val_loss: 1.7423 - val_accuracy: 0.3164 - val_auc: 0.7141
# Epoch 6/50
# 1/1 [==============================] - 0s 88ms/step - loss: 1.7591 - accuracy: 0.2961 - auc: 0.7021 - val_loss: 1.6994 - val_accuracy: 0.3236 - val_auc: 0.7356
# Epoch 7/50
# 1/1 [==============================] - 0s 84ms/step - loss: 1.7162 - accuracy: 0.3006 - auc: 0.7244 - val_loss: 1.6644 - val_accuracy: 0.3300 - val_auc: 0.7512
# Epoch 8/50
# 1/1 [==============================] - 0s 99ms/step - loss: 1.6811 - accuracy: 0.3084 - auc: 0.7403 - val_loss: 1.6357 - val_accuracy: 0.3412 - val_auc: 0.7619
# Epoch 9/50
# 1/1 [==============================] - 0s 94ms/step - loss: 1.6523 - accuracy: 0.3181 - auc: 0.7518 - val_loss: 1.6117 - val_accuracy: 0.3516 - val_auc: 0.7700
# Epoch 10/50
# 1/1 [==============================] - 0s 87ms/step - loss: 1.6281 - accuracy: 0.3298 - auc: 0.7606 - val_loss: 1.5911 - val_accuracy: 0.3597 - val_auc: 0.7769
# Epoch 11/50
# 1/1 [==============================] - 0s 109ms/step - loss: 1.6071 - accuracy: 0.3422 - auc: 0.7679 - val_loss: 1.5727 - val_accuracy: 0.3773 - val_auc: 0.7824
# Epoch 12/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1.5883 - accuracy: 0.3538 - auc: 0.7741 - val_loss: 1.5559 - val_accuracy: 0.3845 - val_auc: 0.7873
# Epoch 13/50
# 1/1 [==============================] - 0s 92ms/step - loss: 1.5709 - accuracy: 0.3659 - auc: 0.7799 - val_loss: 1.5403 - val_accuracy: 0.3921 - val_auc: 0.7920
# Epoch 14/50
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5546 - accuracy: 0.3783 - auc: 0.7851 - val_loss: 1.5255 - val_accuracy: 0.3998 - val_auc: 0.7965
# Epoch 15/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1.5390 - accuracy: 0.3870 - auc: 0.7902 - val_loss: 1.5113 - val_accuracy: 0.4074 - val_auc: 0.8006
# Epoch 16/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.5240 - accuracy: 0.3961 - auc: 0.7950 - val_loss: 1.4978 - val_accuracy: 0.4166 - val_auc: 0.8046
# Epoch 17/50
# 1/1 [==============================] - 0s 116ms/step - loss: 1.5096 - accuracy: 0.4067 - auc: 0.7996 - val_loss: 1.4849 - val_accuracy: 0.4234 - val_auc: 0.8083
# Epoch 18/50
# 1/1 [==============================] - 0s 91ms/step - loss: 1.4958 - accuracy: 0.4165 - auc: 0.8039 - val_loss: 1.4727 - val_accuracy: 0.4338 - val_auc: 0.8120
# Epoch 19/50
# 1/1 [==============================] - 0s 81ms/step - loss: 1.4827 - accuracy: 0.4247 - auc: 0.8080 - val_loss: 1.4612 - val_accuracy: 0.4427 - val_auc: 0.8155
# Epoch 20/50
# 1/1 [==============================] - 0s 112ms/step - loss: 1
50
# 1/1 [==============================] - 0s 81ms/step - loss: 1.3310 - accuracy: 0.4981 - auc: 0.8482 - val_loss: 1.3279 - val_accuracy: 0.4888 - val_auc: 0.8486
# Epoch 40/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3264 - accuracy: 0.4998 - auc: 0.8492 - val_loss: 1.3238 - val_accuracy: 0.4888 - val_auc: 0.8494
# Epoch 41/50
# 1/1 [==============================] - 0s 96ms/step - loss: 1.3219 - accuracy: 0.5009 - auc: 0.8502 - val_loss: 1.3198 - val_accuracy: 0.4912 - val_auc: 0.8502
# Epoch 42/50
# 1/1 [==============================] - 0s 80ms/step - loss: 1.3175 - accuracy: 0.5028 - auc: 0.8511 - val_loss: 1.3159 - val_accuracy: 0.4928 - val_auc: 0.8511
# Epoch 43/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3133 - accuracy: 0.5025 - auc: 0.8521 - val_loss: 1.3120 - val_accuracy: 0.4932 - val_auc: 0.8519
# Epoch 44/50
# 1/1 [==============================] - 0s 92ms/step - loss: 1.3091 - accuracy: 0.5027 - auc: 0.8530 - val_loss: 1.3082 - val_accuracy: 0.4944 - val_auc: 0.8529
# Epoch 45/50
# 1/1 [==============================] - 0s 81ms/step - loss: 1.3051 - accuracy: 0.5039 - auc: 0.8539 - val_loss: 1.3045 - val_accuracy: 0.4960 - val_auc: 0.8536
# Epoch 46/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1.3011 - accuracy: 0.5057 - auc: 0.8549 - val_loss: 1.3008 - val_accuracy: 0.4960 - val_auc: 0.8546
# Epoch 47/50
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2972 - accuracy: 0.5073 - auc: 0.8558 - val_loss: 1.2972 - val_accuracy: 0.4972 - val_auc: 0.8555
# Epoch 48/50
# 1/1 [==============================] - 0s 94ms/step - loss: 1.2934 - accuracy: 0.5071 - auc: 0.8567 - val_loss: 1.2936 - val_accuracy: 0.4976 - val_auc: 0.8561
# Epoch 49/50
# 1/1 [==============================] - 0s 77ms/step - loss: 1.2896 - accuracy: 0.5075 - auc: 0.8575 - val_loss: 1.2901 - val_accuracy: 0.4992 - val_auc: 0.8569
# Epoch 50/50
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2859 - accuracy: 0.5098 - auc: 0.8584 - val_loss: 1.2866 - val_accuracy: 0.5008 - val_auc: 0.8578

# %%
history_dict=history_w.history
loss_w=history_dict['loss']
val_loss_w=history_dict['val_loss']

acc_w=history_dict['accuracy']
val_acc_w=history_dict['val_accuracy']

auc_w=history_dict['auc']
val_auc_w=history_dict['val_auc']

# %%
fig, ax=plt.subplots()
ln1=ax.plot(epochs,loss_w,'m', label='Training Loss')
ln2=ax.plot(epochs,val_loss_w,'mo', label='Validation Loss')

ax2=ax.twinx()
ln3=ax2.plot(epochs,auc_w,'b', label='Training AUC')
ln3=ax2.plot(epochs,val_auc_w,'bo', label='Validation AUC')

ax.set_title('Word Classification')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax2.set_ylabel('AUC - ROC')

plt.xticks(ticks)
ax.legend(loc=(0.6,0.2))
ax2.legend(loc=(0.6,0.7))
#fig.legend(loc=(0.6,0.4))
plt.tight_layout()
#plt.savefig('./New_without_CNN/loss_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_w,'bo',label='Training loss')
plt.plot(epochs,val_loss_w,'b',label='Validation loss')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Word Classification')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/loss_word_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_w,'bo',label='Training acc')
plt.plot(epochs,val_acc_w,'b',label='Validation acc')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Word Classification')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/accuracy_word_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_w,'bo',label='Training AUC')
plt.plot(epochs,val_auc_w,'b',label='Validation AUC')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Word Classification')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/AUC_word_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
#COMPARE

# %%
save_specifier='standard_mfcc_32_16_tanh_softmax_adam_0.005_batchfull'

# %%
fig, ax=plt.subplots()
ln1=ax.plot(epochs,loss_v,'b', label='Vowel Loss')
ln2=ax.plot(epochs,loss_w,'r', label='Word Loss')

ax2=ax.twinx()
ln3=ax2.plot(epochs,auc_v,'b--', label='Vowel AUC')
ln3=ax2.plot(epochs,auc_w,'r--', label='Word AUC')

ax.set_title('Loss and AUC Comparison')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax2.set_ylabel('AUC - ROC')

plt.xticks(ticks)
ax.legend(loc=(0.6,0.2))
ax2.legend(loc=(0.6,0.76))
#fig.legend(loc=(0.6,0.4))
plt.tight_layout()
#plt.savefig('./New_without_CNN/loss_vowel_'+save_specifier+'.pdf',format='pdf', dpi=600)

# %%
#sns.reset()
#sns.reset_orig()
plt.figure(figsize=(10,4))
plt.plot(epochs,loss_v,'r',label='Vowel')
plt.plot(epochs,loss_w,'b',label='Word')
plt.title('Loss comparison')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/loss_compare_'+save_specifier+'.pdf',format='pdf',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,acc_v,'r',label='Vowel')
plt.plot(epochs,acc_w,'b',label='Word')
plt.title('Accuracy comparison')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/accuracy_compare_'+save_specifier+'.pdf',format='pdf',dpi=600)

# %%
plt.figure(figsize=(10,4))
plt.plot(epochs,auc_v,'r',label='Vowel')
plt.plot(epochs,auc_w,'b',label='Word')
plt.title('AUC comparison')
plt.xticks(epochs,rotation=90)
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.tight_layout()
#plt.savefig('./New_without_CNN/AUC_compare_'+save_specifier+'.pdf',format='pdf',dpi=600)

# %%
all_compare_df=pd.DataFrame({'loss_v':loss_v,
                      'val_loss_v':val_loss_v,
                      'acc_v':acc_v,
                      'val_acc_v':val_acc_v,
                      'auc_v':auc_v,
                      'val_auc_v':val_auc_v,
                      'loss_w':loss_w,
                      'val_loss_w':val_loss_w,
                      'acc_w':acc_w,
                      'val_acc_w':val_acc_w,
                      'auc_w':auc_w,
                      'val_auc_w':val_auc_w
                     })

all_compare_df.to_csv('./New_without_CNN/all_compare_data_'+save_specifier+'.csv')

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  1.087982    1.079178  0.578892   0.576316  0.914252   0.914130  1.465496
# 46  1.073246    1.063786  0.580471   0.586316  0.916134   0.916380  1.460930
# 47  1.058198    1.051638  0.585735   0.577368  0.918239   0.917834  1.456578
# 48  1.043170    1.040124  0.585867   0.578421  0.920454   0.919898  1.452407
# 49  1.030735    1.028717  0.590604   0.581053  0.922445   0.921268  1.448298
#
#     val_loss_w     acc_w  val_acc_w     auc_w  val_auc_w
# 45    1.461363  0.433841   0.435846  0.808475   0.810116
# 46    1.456924  0.435345   0.437049  0.809607   0.811218
# 47    1.452782  0.435445   0.443865  0.810850   0.812264
# 48    1.448659  0.439755   0.447875  0.812117   0.813237
# 49    1.444540  0.444968   0.446672  0.813397   0.814203

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  0.747012    0.753977  0.741413   0.727895  0.960994   0.959738  1.281573
# 46  0.740706    0.747679  0.742203   0.727895  0.961514   0.960330  1.277932
# 47  0.734629    0.741603  0.743387   0.728421  0.961970   0.960810  1.274361
# 48  0.728761    0.735736  0.745493   0.731053  0.962445   0.961305  1.270858
# 49  0.723083    0.730062  0.745756   0.734211  0.962883   0.961810  1.267420
#
#     val_loss_w     acc_w  val_acc_w     auc_w  val_auc_w
# 45    1.291772  0.509824   0.504010  0.859364   0.856465
# 46    1.287836  0.511628   0.503609  0.860304   0.857371
# 47    1.283999  0.512831   0.503609  0.861195   0.858353
# 48    1.280256  0.513031   0.506816  0.862042   0.859321
# 49    1.276603  0.514635   0.510024  0.862903   0.860176

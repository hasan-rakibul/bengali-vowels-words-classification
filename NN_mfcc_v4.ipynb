# %%
import os,librosa
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers as opt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses
import pandas as pd
import seaborn as sns
from sklearn.metrics import precision_score,recall_score,f1_score, cohen_kappa_score

# %%
seed=15
n_MFCC=13
column_names= ['MFCC_'+str(i) for i in range(1,n_MFCC+1)]

# %%
DATA_PATH="./Vowel_Data/Vowel/"

# %%
def get_mfcc(file_path):
    wave, sr= librosa.load(file_path, mono=True, sr=None)
    mfcc=librosa.feature.mfcc(wave,sr=sr,n_mfcc=n_MFCC)
    mfcc_df=pd.DataFrame(mfcc.T,columns=column_names) #convert array to pandas df
    return mfcc_df

def get_all_mfcc(path=DATA_PATH):
    labels=sorted(os.listdir(path))
    all_mfcc=pd.DataFrame() #empty dataframe to store all_mfccs
    
    for label_index,label in enumerate(labels):
        folder_mfcc=pd.DataFrame() #empty dataframe to store mfcc of indivuals vowels/words i.e. folders

        speech_files=[path + label + '/' + file for file in sorted(os.listdir(path+'/'+label))]
        for file in tqdm(speech_files,"Reading Speech of label -'{}'".format(label)):
            #print(file)
            individual_mfcc=get_mfcc(file_path=file)
            folder_mfcc=folder_mfcc.append(individual_mfcc,ignore_index=True)
        
        folder_mfcc['label']=label_index  #new columns for encoding label
        
        all_mfcc=all_mfcc.append(folder_mfcc,ignore_index=True)
        
    return all_mfcc

def get_train_test(split_ratio=0.8,random_state=42):
    all_mfccs=get_all_mfcc()
    
    y=all_mfccs['label'].values
    
    only_mfcc=all_mfccs.drop(labels=['label'],axis=1)
    standard_mfcc=(only_mfcc-only_mfcc.mean())/only_mfcc.std()
    X=standard_mfcc.values

    assert X.shape[0] == len(y)
    return X,y

# %%
X,y=get_train_test()
# Out:
# Reading Speech of label -'vowel1': 100%|██████████| 40/40 [00:00<00:00, 42.96it/s]
# Reading Speech of label -'vowel2': 100%|██████████| 40/40 [00:00<00:00, 101.50it/s]
# Reading Speech of label -'vowel3': 100%|██████████| 40/40 [00:00<00:00, 95.53it/s]
# Reading Speech of label -'vowel4': 100%|██████████| 40/40 [00:00<00:00, 110.66it/s]
# Reading Speech of label -'vowel5': 100%|██████████| 40/40 [00:00<00:00, 103.53it/s]
# Reading Speech of label -'vowel6': 100%|██████████| 40/40 [00:00<00:00, 113.76it/s]
# Reading Speech of label -'vowel7': 100%|██████████| 40/40 [00:00<00:00, 114.34it/s]

# %%
model_v.metrics_names[2]
# Out:
# 'auc'

# %%
kfold=StratifiedKFold(n_splits=4,shuffle=True,random_state=seed)
cv_acc=[]
cv_AUC=[]
#cv_precision=[]
#cv_recall=[]
cv_f1=[]
cv_kappa=[]

for train,test in kfold.split(X,y):
    y_hot=to_categorical(y)
    
    model_v=Sequential()
    model_v.add(Dense(32, activation='tanh',input_shape=(X[train].shape[1],)))
    model_v.add(Dense(16, activation='tanh'))
    model_v.add(Dense(7, activation='softmax'))
    
    model_v.compile(
        #optimizer=opt.SGD(learning_rate=0.005,momentum=0.9),
        optimizer=opt.Adam(learning_rate=0.005),
        #loss=losses.CategoricalCrossentropy(),
        loss='categorical_crossentropy',
        #metrics=['AUC'],
        #metrics=['accuracy']#,
        metrics=[['accuracy','AUC']]
    )
    model_v.fit(X[train], y_hot[train], epochs=50, batch_size=X[train].shape[0],verbose=0)
    
    scores=model_v.evaluate(X[test],y_hot[test],verbose=0)
    
    print("%s: %.2f" % (model_v.metrics_names[1],scores[1]))
    print("%s: %.2f" % (model_v.metrics_names[2],scores[2]))
    
    yhat_classes = model_v.predict_classes(X[test], verbose=0)
    
    #precision = precision_score(y[test], yhat_classes,average='weighted')*100
    #print('Precision: %.2f%%' % precision)
    
    #recall = recall_score(y[test], yhat_classes,average='weighted')*100
    #print('Recall: %.2f%%' % recall)
    
    f1 = f1_score(y[test], yhat_classes,average='weighted')
    print('F1: %.2f' % f1)
    
    kappa = cohen_kappa_score(y[test], yhat_classes)
    print('Cohens kappa: %.2f' % kappa)
    
    cv_acc.append(scores[1])
    cv_AUC.append(scores[2])
    #cv_precision.append(precision)
    #cv_recall.append(recall)
    cv_f1.append(f1)
    cv_kappa.append(kappa)
    
    print(' ')
    
print("Overall acc: %.2f (+/- %.2f)" % (np.mean(cv_acc),np.std(cv_acc)))
print("Overall AUC: %.2f (+/- %.2f)" % (np.mean(cv_AUC),np.std(cv_AUC)))
#print("Overall precision: %.2f%% (+/- %.2f%%)" % (np.mean(cv_precision),np.std(cv_precision)))
#print("Overall recall: %.2f%% (+/- %.2f%%)" % (np.mean(cv_recall),np.std(cv_recall)))
print("Overall f1: %.2f (+/- %.2f)" % (np.mean(cv_f1),np.std(cv_f1)))
print("Overall kappa: %.2f (+/- %.2f)" % (np.mean(cv_kappa),np.std(cv_kappa)))
# Out:
# accuracy: 0.73
# auc: 0.96
# F1: 0.72
# Cohens kappa: 0.69
#
# accuracy: 0.75
# auc: 0.96
# F1: 0.75
# Cohens kappa: 0.71
#
# accuracy: 0.73
# auc: 0.96
# F1: 0.72
# Cohens kappa: 0.69
#
# accuracy: 0.74
# auc: 0.96
# F1: 0.73
# Cohens kappa: 0.69
#
# Overall acc: 0.74 (+/- 0.01)
# Overall AUC: 0.96 (+/- 0.00)
# Overall f1: 0.73 (+/- 0.01)
# Overall kappa: 0.69 (+/- 0.01)

# %%
yhat_classes = model_v.predict_classes(X[test], verbose=0)

# %%
yhat_probs = model_v.predict(X[test], verbose=0)

# %%
precision = precision_score(y[test], yhat_classes,average='weighted')
print('Precision: %f' % precision)
# Out:
# Precision: 0.729089

# %%
kappa = cohen_kappa_score(y[test], yhat_classes)
print('Cohens kappa: %f' % kappa)
# Out:
# Cohens kappa: 0.689937

# %%
cv_data_df=pd.DataFrame(data={'acc':cv_acc,
                              'AUC':cv_AUC,
                              'F1':cv_f1,
                              'Kappa':cv_kappa}
                       )

# %%
cv_data_df
# Out:
#           x         y
# 0  0.746602  0.708625
# 1  0.730126  0.690870
# 2  0.734819  0.703409
# 3  0.750483  0.713930

# %%
history_w=model_w.fit(X_train, y_train_hot, epochs=50, batch_size=X_train.shape[0], validation_data=(X_test,y_test_hot))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 332ms/step - loss: 1.9930 - accuracy: 0.1671 - auc: 0.5217 - val_loss: 1.9290 - val_accuracy: 0.2057 - val_auc: 0.5723
# Epoch 2/50
# 1/1 [==============================] - 0s 85ms/step - loss: 1.9302 - accuracy: 0.1946 - auc: 0.5724 - val_loss: 1.8725 - val_accuracy: 0.2330 - val_auc: 0.6255
# Epoch 3/50
# 1/1 [==============================] - 0s 104ms/step - loss: 1.8739 - accuracy: 0.2257 - auc: 0.6244 - val_loss: 1.8220 - val_accuracy: 0.2686 - val_auc: 0.6714
# Epoch 4/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.8234 - accuracy: 0.2566 - auc: 0.6694 - val_loss: 1.7768 - val_accuracy: 0.2947 - val_auc: 0.7060
# Epoch 5/50
# 1/1 [==============================] - 0s 82ms/step - loss: 1.7780 - accuracy: 0.2839 - auc: 0.7045 - val_loss: 1.7362 - val_accuracy: 0.3240 - val_auc: 0.7308
# Epoch 6/50
# 1/1 [==============================] - 0s 110ms/step - loss: 1.7370 - accuracy: 0.3103 - auc: 0.7300 - val_loss: 1.6997 - val_accuracy: 0.3512 - val_auc: 0.7486
# Epoch 7/50
# 1/1 [==============================] - 0s 85ms/step - loss: 1.7000 - accuracy: 0.3400 - auc: 0.7483 - val_loss: 1.6667 - val_accuracy: 0.3681 - val_auc: 0.7613
# Epoch 8/50
# 1/1 [==============================] - 0s 107ms/step - loss: 1.6666 - accuracy: 0.3613 - auc: 0.7616 - val_loss: 1.6370 - val_accuracy: 0.3817 - val_auc: 0.7713
# Epoch 9/50
# 1/1 [==============================] - 0s 110ms/step - loss: 1.6363 - accuracy: 0.3779 - auc: 0.7717 - val_loss: 1.6102 - val_accuracy: 0.3917 - val_auc: 0.7791
# Epoch 10/50
# 1/1 [==============================] - 0s 91ms/step - loss: 1.6088 - accuracy: 0.3944 - auc: 0.7797 - val_loss: 1.5859 - val_accuracy: 0.4018 - val_auc: 0.7854
# Epoch 11/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1.5838 - accuracy: 0.4064 - auc: 0.7864 - val_loss: 1.5638 - val_accuracy: 0.4146 - val_auc: 0.7911
# Epoch 12/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.5610 - accuracy: 0.4144 - auc: 0.7921 - val_loss: 1.5436 - val_accuracy: 0.4266 - val_auc: 0.7958
# Epoch 13/50
# 1/1 [==============================] - 0s 85ms/step - loss: 1.5402 - accuracy: 0.4185 - auc: 0.7974 - val_loss: 1.5252 - val_accuracy: 0.4290 - val_auc: 0.8002
# Epoch 14/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.5211 - accuracy: 0.4265 - auc: 0.8020 - val_loss: 1.5084 - val_accuracy: 0.4350 - val_auc: 0.8042
# Epoch 15/50
# 1/1 [==============================] - 0s 107ms/step - loss: 1.5034 - accuracy: 0.4317 - auc: 0.8062 - val_loss: 1.4931 - val_accuracy: 0.4415 - val_auc: 0.8078
# Epoch 16/50
# 1/1 [==============================] - 0s 87ms/step - loss: 1.4872 - accuracy: 0.4382 - auc: 0.8102 - val_loss: 1.4791 - val_accuracy: 0.4455 - val_auc: 0.8111
# Epoch 17/50
# 1/1 [==============================] - 0s 110ms/step - loss: 1.4723 - accuracy: 0.4424 - auc: 0.8137 - val_loss: 1.4663 - val_accuracy: 0.4491 - val_auc: 0.8140
# Epoch 18/50
# 1/1 [==============================] - 0s 86ms/step - loss: 1.4586 - accuracy: 0.4491 - auc: 0.8170 - val_loss: 1.4548 - val_accuracy: 0.4519 - val_auc: 0.8167
# Epoch 19/50
# 1/1 [==============================] - 0s 89ms/step - loss: 1.4460 - accuracy: 0.4548 - auc: 0.8200 - val_loss: 1.4444 - val_accuracy: 0.4523 - val_auc: 0.8191
# Epoch 20/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.4345 - accuracy: 0.4602 - auc: 0.8227 - val_loss: 1.4350 - val_accuracy: 0.4547 - val_auc: 0.8214
# Epoch 21/50
# 1/1 [==============================] - 0s 96ms/step - loss: 1.4239 - accuracy: 0.4653 - auc: 0.8252 - val_loss: 1.4265 - val_accuracy: 0.4611 - val_auc: 0.8232
# Epoch 22/50
# 1/1 [==============================] - 0s 99ms/step - loss: 1.4143 - accuracy: 0.4698 - auc: 0.8275 - val_loss: 1.4187 - val_accuracy: 0.4659 - val_auc: 0.8251
# Epoch 23/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.4054 - accuracy: 0.4735 - auc: 0.8297 - val_loss: 1.4115 - val_accuracy: 0.4695 - val_auc: 0.8268
# Epoch 24/50
# 1/1 [==============================] - 0s 90ms/step - loss: 1.3971 - accuracy: 0.4765 - auc: 0.8316 - val_loss: 1.4048 - val_accuracy: 0.4751 - val_auc: 0.8284
# Epoch 25/50
# 1/1 [==============================] - 0s 82ms/step - loss: 1.3895 - accuracy: 0.4807 - auc: 0.8334 - val_loss: 1.3985 - val_accuracy: 0.4743 - val_auc: 0.8300
# Epoch 26/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.3822 - accuracy: 0.4832 - auc: 0.8351 - val_loss: 1.3924 - val_accuracy: 0.4727 - val_auc: 0.8314
# Epoch 27/50
# 1/1 [==============================] - 0s 109ms/step - loss: 1.3754 - accuracy: 0.4855 - auc: 0.8368 - val_loss: 1.3866 - val_accuracy: 0.4751 - val_auc: 0.8328
# Epoch 28/50
# 1/1 [==============================] - 0s 85ms/step - loss: 1.3688 - accuracy: 0.4876 - auc: 0.8383 - val_loss: 1.3809 - val_accuracy: 0.4763 - val_auc: 0.8340
# Epoch 29/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.3625 - accuracy: 0.4887 - auc: 0.8398 - val_loss: 1.3753 - val_accuracy: 0.4763 - val_auc: 0.8354
# Epoch 30/50
# 1/1 [==============================] - 0s 87ms/step - loss: 1.3565 - accuracy: 0.4898 - auc: 0.8412 - val_loss: 1.3697 - val_accuracy: 0.4804 - val_auc: 0.8367
# Epoch 31/50
# 1/1 [==============================] - 0s 97ms/step - loss: 1.3506 - accuracy: 0.4921 - auc: 0.8426 - val_loss: 1.3643 - val_accuracy: 0.4808 - val_auc: 0.8380
# Epoch 32/50
# 1/1 [==============================] - 0s 106ms/step - loss: 1.3450 - accuracy: 0.4938 - auc: 0.8439 - val_loss: 1.3588 - val_accuracy: 0.4812 - val_auc: 0.8393
# Epoch 33/50
# 1/1 [==============================] - 0s 78ms/step - loss: 1.3395 - accuracy: 0.4946 - auc: 0.8450 - val_loss: 1.3535 - val_accuracy: 0.4828 - val_auc: 0.8406
# Epoch 34/50
# 1/1 [==============================] - 0s 102ms/step - loss: 1.3342 - accuracy: 0.4958 - auc: 0.8463 - val_loss: 1.3481 - val_accuracy: 0.4844 - val_auc: 0.8420
# Epoch 35/50
# 1/1 [==============================] - 0s 81ms/step - loss: 1.3290 - accuracy: 0.4977 - auc: 0.8475 - val_loss: 1.3428 - val_accuracy: 0.4864 - val_auc: 0.8432
# Epoch 36/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.3240 - accuracy: 0.4993 - auc: 0.8487 - val_loss: 1.3376 - val_accuracy: 0.4864 - val_auc: 0.8446
# Epoch 37/50
# 1/1 [==============================] - 0s 93ms/step - loss: 1.3191 - accuracy: 0.5000 - auc: 0.8498 - val_loss: 1.3325 - val_accuracy: 0.4908 - val_auc: 0.8459
# Epoch 38/50
# 1/1 [==============================] - 0s 79ms/step - loss: 1.3144 - accuracy: 0.5005 - auc: 0.8510 - val_loss: 1.3275 - val_accuracy: 0.4920 - val_auc: 0.8472
# Epoch 39/50
# 1/1 [==============================] - 0s 80ms/step - loss: 1.3098 - accuracy: 0.5018 - auc: 0.8521 - val_loss: 1.3225 - val_accuracy: 0.4944 - val_auc: 0.8485
# Epoch 40/50
# 1/1 [==============================] - 0s 116ms/step - loss: 1.3054 - accuracy: 0.5048 - auc: 0.8533 - val_loss: 1.3178 - val_accuracy: 0.4944 - val_auc: 0.8497
# Epoch 41/50
# 1/1 [==============================] - 0s 78ms/step - loss: 1.3011 - accuracy: 0.5056 - auc: 0.8543 - val_loss: 1.3131 - val_accuracy: 0.4964 - val_auc: 0.8508
# Epoch 42/50
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2970 - accuracy: 0.5080 - auc: 0.8554 - val_loss: 1.3086 - val_accuracy: 0.4972 - val_auc: 0.8520
# Epoch 43/50
# 1/1 [==============================] - 0s 117ms/step - loss: 1.2930 - accuracy: 0.5091 - auc: 0.8565 - val_loss: 1.3042 - val_accuracy: 0.4996 - val_auc: 0.8533
# Epoch 44/50
# 1/1 [==============================] - 0s 78ms/step - loss: 1.2891 - accuracy: 0.5089 - auc: 0.8574 - val_loss: 1.3000 - val_accuracy: 0.5024 - val_auc: 0.8543
# Epoch 45/50
# 1/1 [==============================] - 0s 91ms/step - loss: 1.2853 - accuracy: 0.5100 - auc: 0.8584 - val_loss: 1.2958 - val_accuracy: 0.5028 - val_auc: 0.8554
# Epoch 46/50
# 1/1 [==============================] - 0s 119ms/step - loss: 1.2816 - accuracy: 0.5098 - auc: 0.8594 - val_loss: 1.2918 - val_accuracy: 0.5040 - val_auc: 0.8565
# Epoch 47/50
# 1/1 [==============================] - 0s 284ms/step - loss: 1.2779 - accuracy: 0.5116 - auc: 0.8603 - val_loss: 1.2878 - val_accuracy: 0.5036 - val_auc: 0.8574
# Epoch 48/50
# 1/1 [==============================] - 0s 88ms/step - loss: 1.2744 - accuracy: 0.5128 - auc: 0.8612 - val_loss: 1.2840 - val_accuracy: 0.5036 - val_auc: 0.8584
# Epoch 49/50
# 1/1 [==============================] - 0s 99ms/step - loss: 1.2709 - accuracy: 0.5130 - auc: 0.8620 - val_loss: 1.2803 - val_accuracy: 0.5068 - val_auc: 0.8593
# Epoch 50/50
# 1/1 [==============================] - 0s 76ms/step - loss: 1.2674 - accuracy: 0.5146 - auc: 0.8629 - val_loss: 1.2766 - val_accuracy: 0.5100 - val_auc: 0.8602

# %%
save_specifier='standard_mfcc_32_16_tanh_softmax_adam_0.005_batchfull'

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  1.087982    1.079178  0.578892   0.576316  0.914252   0.914130  1.465496
# 46  1.073246    1.063786  0.580471   0.586316  0.916134   0.916380  1.460930
# 47  1.058198    1.051638  0.585735   0.577368  0.918239   0.917834  1.456578
# 48  1.043170    1.040124  0.585867   0.578421  0.920454   0.919898  1.452407
# 49  1.030735    1.028717  0.590604   0.581053  0.922445   0.921268  1.448298
#
#     val_loss_w     acc_w  val_acc_w     auc_w  val_auc_w
# 45    1.461363  0.433841   0.435846  0.808475   0.810116
# 46    1.456924  0.435345   0.437049  0.809607   0.811218
# 47    1.452782  0.435445   0.443865  0.810850   0.812264
# 48    1.448659  0.439755   0.447875  0.812117   0.813237
# 49    1.444540  0.444968   0.446672  0.813397   0.814203

# %%
all_compare_df.tail()
# Out:
#       loss_v  val_loss_v     acc_v  val_acc_v     auc_v  val_auc_v    loss_w  \
# 45  0.747012    0.753977  0.741413   0.727895  0.960994   0.959738  1.281573
# 46  0.740706    0.747679  0.742203   0.727895  0.961514   0.960330  1.277932
# 47  0.734629    0.741603  0.743387   0.728421  0.961970   0.960810  1.274361
# 48  0.728761    0.735736  0.745493   0.731053  0.962445   0.961305  1.270858
# 49  0.723083    0.730062  0.745756   0.734211  0.962883   0.961810  1.267420
#
#     val_loss_w     acc_w  val_acc_w     auc_w  val_auc_w
# 45    1.291772  0.509824   0.504010  0.859364   0.856465
# 46    1.287836  0.511628   0.503609  0.860304   0.857371
# 47    1.283999  0.512831   0.503609  0.861195   0.858353
# 48    1.280256  0.513031   0.506816  0.862042   0.859321
# 49    1.276603  0.514635   0.510024  0.862903   0.860176
